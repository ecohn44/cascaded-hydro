# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, LassoCV
import statsmodels.api as sm

# %%
import preprocessing as preproc
# help(preproc)

# %%
int_freq = 30

# %% [markdown]
# # Data Collection

# %%
start_date = '2009-01-01'
end_date = '2024-12-31'
date_range = preproc.create_date_range(start_date, end_date)

# %% [markdown]
# ### Downstream Data (Inflow)

# %%
inflow_site = '14128600'

## Collect Dataset #1
df1 = preproc.preprocess(inflow_site, int_freq, start_date, end_date)
# Out:
# COLUMBIA RIVER AT STEVENSON, WA
# Removed 24 duplicate rows
#
# Removed 0 rows with NaN in '00065'
#
# Imputed 201 rows

# %% [markdown]
# ### Upstream Data (Outflow)

# %%
outflow_site = '14105700'

## Collect Dataset #2
df2 = preproc.preprocess(outflow_site, int_freq, start_date, end_date)
# Out:
# COLUMBIA RIVER AT THE DALLES, OR
# Removed 32 duplicate rows
#
# Removed 437 rows with NaN in '00065'
#
# Imputed 887 rows

# %% [markdown]
# # Training & Test Set

# %%
train_start_year = '2008'
test_start_year = '2024'

# %%
## Merge downstream and upstream data

df_range = preproc.dataset_merge(df1, df2, train_start_year, "full")

# %%
## Create lag features

p = 7 
up_feat = True
down_feat = True 

df_reg, feature_cols = preproc.create_lag_features(df_range, p, up_feat, down_feat)

# %%
## Split the data into training and testing sets

train_data = df_reg[(df_reg.index < test_start_year)]
test_data = df_reg[(df_reg.index >= test_start_year)]

X_train = train_data[feature_cols]
y_train = train_data['y_norm']

X_test = test_data[feature_cols]
y_test = test_data['y_norm']

# %% [markdown]
# # M0: Previous Term Forecaster

# %%
## Simulate Model Forecasting
# Model Output (y_hat): y[t-1]
# Ground Truth (y): y[t]

fitted_vals0 = y_train[:-1].values
y_train0 = y_train[1:].values

# %% [markdown]
# ## Residuals

# %%
## Residuals = y[t] - y[t-1]

residuals0 = y_train0 - fitted_values0

# %%
plt.hist(residuals0, bins = 100)
plt.title('M0: Training Residuals')
plt.xlim([-.5, .5])
plt.show()

# %%
preproc.plot_variance("M0", fitted_vals0, residuals0)

# %% [markdown]
# ## Evaluation

# %%
y_pred0 = y_test[:-1] # Exclude the last element
y_test0 = y_test[1:]  # Exclude the first element

# %%
preproc.print_test_stats(y_test0, y_pred0)
# Out:
# RMSE: 0.059
# MAE: 0.044
# R²: 0.994

# %%
preproc.plot_forecasts("M0", y_test0, y_pred0)

# %% [markdown]
# # M1: Linear Regression

# %%
# Step 1: Add constant (intercept)
X_train_const = sm.add_constant(X_train)

# Step 2: Fit OLS model
model = sm.OLS(y_train, X_train_const).fit(cov_type='HC1') # Heteroskedasticity-consistent

# Step 3: View summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 y_norm   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.229e+07
# Date:                Mon, 09 Jun 2025   Prob (F-statistic):               0.00
# Time:                        12:02:10   Log-Likelihood:             4.9408e+05
# No. Observations:              262938   AIC:                        -9.881e+05
# Df Residuals:                  262922   BIC:                        -9.880e+05
# Df Model:                          15
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.536e-06   7.15e-05      0.105      0.916      -0.000       0.000
# day_sin       -0.0015      0.000    -12.585      0.000      -0.002      -0.001
# day_cos    -1.104e-05      0.000     -0.094      0.925      -0.000       0.000
# x_norm        -0.0385      0.002    -16.434      0.000      -0.043      -0.034
# X_Lag_1        0.1024      0.004     28.451      0.000       0.095       0.109
# X_Lag_2        0.0223      0.003      6.876      0.000       0.016       0.029
# X_Lag_3        0.1963      0.003     59.409      0.000       0.190       0.203
# X_Lag_4       -0.0023      0.005     -0.521      0.602      -0.011       0.006
# X_Lag_5       -0.2822      0.003    -85.245      0.000      -0.289      -0.276
# X_Lag_6        0.0066      0.004      1.759      0.079      -0.001       0.014
# Y_Lag_1        1.4304      0.011    127.402      0.000       1.408       1.452
# Y_Lag_2       -0.4466      0.017    -25.757      0.000      -0.481      -0.413
# Y_Lag_3        0.0406      0.009      4.608      0.000       0.023       0.058
# Y_Lag_4        0.0486      0.005      9.505      0.000       0.039       0.059
# Y_Lag_5       -0.1021      0.005    -21.053      0.000      -0.112      -0.093
# Y_Lag_6        0.0233      0.003      9.181      0.000       0.018       0.028
# ==============================================================================
# Omnibus:                    95606.957   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         57237012.409
# Skew:                          -0.078   Prob(JB):                         0.00
# Kurtosis:                      75.280   Cond. No.                         251.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# ## Residuals

# %%
residuals1 = model.resid
fitted_vals1 = model.fittedvalues

# %%
# Checking for Heteroskedasticity

preproc.plot_variance("M1", fitted_vals1, residuals1)

# %% [markdown]
# ## Evaluation

# %%
X_test_const = sm.add_constant(X_test)  # Add intercept term
X_test_const['const'] = np.ones(len(X_test))
X_test_const = pd.DataFrame(X_test_const, columns=model.model.exog_names)
y_pred1 = model.predict(X_test_const)

# %%
preproc.plot_forecasts("M1", y_test, y_pred1)

# %%
preproc.print_test_stats(y_test, y_pred1)
# Out:
# RMSE: 0.032
# MAE: 0.023
# R²: 0.998

# %% [markdown]
# # M2: LASSO

# %%
spline_feat = True

if spline_feat:
    lasso_train = X_train_M3_full.copy()
    lasso_test = X_test_M3_full.copy()
else:
    lasso_train = X_train.copy() 
    lasso_test = X_test.copy()

# %%
## Cross-Validation for Hyperparamter Finetuning

lasso_cv = LassoCV(cv=5, positive=True).fit(lasso_train, y_train)
alpha_star = lasso_cv.alpha_
print("Best alpha:", alpha_star)
# Out:
# Best alpha: 0.0010135855791023928

# %%
## Create and fit LASSO model

#lasso = Lasso(alpha=0, positive=True)  # alpha is the regularization strength (higher = more shrinkage)
lasso = Lasso(alpha=alpha_star, positive=True)
lasso.fit(lasso_train, y_train)
# Out:
# Lasso(alpha=0.0010135855791023928, positive=True)

# %%
## Make predictions

y_pred2 = pd.Series(lasso.predict(lasso_test))

# %%
## View coefficients

coefficients = pd.Series(lasso.coef_, index=lasso_train.columns)
print(coefficients)
# Out:
# day_sin                                    0.000000e+00
# day_cos                                    3.964298e-07
# x_norm                                     1.304333e-02
# X_Lag_1                                    0.000000e+00
# X_Lag_2                                    0.000000e+00
# X_Lag_3                                    0.000000e+00
# X_Lag_4                                    0.000000e+00
# X_Lag_5                                    0.000000e+00
# X_Lag_6                                    0.000000e+00
# Y_Lag_1                                    9.866075e-01
# Y_Lag_2                                    0.000000e+00
# Y_Lag_3                                    0.000000e+00
# Y_Lag_4                                    0.000000e+00
# Y_Lag_5                                    0.000000e+00
# Y_Lag_6                                    0.000000e+00
# Intercept                                  0.000000e+00
# bs(t, df=4, include_intercept=False)[0]    0.000000e+00
# bs(t, df=4, include_intercept=False)[1]    0.000000e+00
# bs(t, df=4, include_intercept=False)[2]    0.000000e+00
# bs(t, df=4, include_intercept=False)[3]    0.000000e+00
# dtype: float64

# %% [markdown]
# ## Residuals

# %%
fitted_vals2 = lasso.predict(lasso_train)

# %%
residuals2 = y_train - fitted_vals2

# %%
plt.hist(residuals2, bins = 100)
plt.title('M2: Training Residuals')
plt.xlim([-.5, .5])
plt.show()

# %%
# Checking for Heteroskedasticity

preproc.plot_variance("M2", fitted_vals2, residuals2)

# %% [markdown]
# ## Evaluation

# %%
preproc.plot_forecasts("M2", y_test, y_pred2)

# %%
preproc.print_test_stats(y_test, y_pred2)
# Out:
# RMSE: 0.058
# MAE: 0.044
# R²: 0.994

# %% [markdown]
# # M3: Spline

# %%
from patsy import dmatrix

# %%
## Create numerical & continuous time variable

X_train_M3 = X_train.copy()
X_train_M3["t"] = (X_train_M3.index - X_train_M3.index[0]).total_seconds() / (3600 * 24)

# %%
## Generate spline

# Natural cubic spline with 4 degrees of freedom (adjust as needed)
spline = dmatrix("bs(t, df=4, include_intercept=False)", data=X_train_M3, return_type='dataframe')

# %%
## Combine spline basis with lag features

X_train_M3_full = pd.concat([X_train_M3.drop(columns="t"), spline], axis=1)

# %%
## Fit the model 

model3 = sm.OLS(y_train, X_train_M3_full).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 y_norm   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.028e+07
# Date:                Mon, 09 Jun 2025   Prob (F-statistic):               0.00
# Time:                        14:09:58   Log-Likelihood:             4.9420e+05
# No. Observations:              262938   AIC:                        -9.884e+05
# Df Residuals:                  262918   BIC:                        -9.882e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# day_sin                                    -0.0018      0.000    -14.798      0.000      -0.002      -0.002
# day_cos                                 -1.602e-08      0.000     -0.000      1.000      -0.000       0.000
# x_norm                                     -0.0388      0.001    -30.703      0.000      -0.041      -0.036
# X_Lag_1                                     0.1023      0.002     57.987      0.000       0.099       0.106
# X_Lag_2                                     0.0225      0.002     12.667      0.000       0.019       0.026
# X_Lag_3                                     0.1965      0.002    110.007      0.000       0.193       0.200
# X_Lag_4                                    -0.0021      0.002     -1.148      0.251      -0.006       0.001
# X_Lag_5                                    -0.2819      0.002   -160.285      0.000      -0.285      -0.278
# X_Lag_6                                     0.0067      0.001      4.595      0.000       0.004       0.010
# Y_Lag_1                                     1.4294      0.002    732.597      0.000       1.426       1.433
# Y_Lag_2                                    -0.4462      0.003   -134.522      0.000      -0.453      -0.440
# Y_Lag_3                                     0.0407      0.003     11.951      0.000       0.034       0.047
# Y_Lag_4                                     0.0487      0.003     14.350      0.000       0.042       0.055
# Y_Lag_5                                    -0.1015      0.003    -31.158      0.000      -0.108      -0.095
# Y_Lag_6                                     0.0223      0.002     13.060      0.000       0.019       0.026
# Intercept                                   0.0049      0.000     13.562      0.000       0.004       0.006
# bs(t, df=4, include_intercept=False)[0]    -0.0075      0.001    -10.255      0.000      -0.009      -0.006
# bs(t, df=4, include_intercept=False)[1]    -0.0049      0.001     -8.709      0.000      -0.006      -0.004
# bs(t, df=4, include_intercept=False)[2]    -0.0054      0.001     -8.412      0.000      -0.007      -0.004
# bs(t, df=4, include_intercept=False)[3]    -0.0038      0.000     -8.131      0.000      -0.005      -0.003
# ==============================================================================
# Omnibus:                    95630.649   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         57246188.379
# Skew:                          -0.081   Prob(JB):                         0.00
# Kurtosis:                      75.285   Cond. No.                         251.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Residuals

# %%
residuals3 = model3.resid
fitted_vals3 = model3.fittedvalues

# %%
preproc.plot_variance("M3", fitted_vals3, residuals3)

# %% [markdown]
# ## Evaluation

# %%
## Prepare test dataset

X_test_M3 = X_test.copy()
X_test_M3["t"] = (X_test.index - X_train.index[0]).total_seconds() / (3600 * 24)

spline_test = dmatrix("bs(t, df=4, include_intercept=False)", data=X_test_M3, return_type='dataframe')
X_test_M3_full = pd.concat([X_test_M3.drop(columns="t"), spline_test], axis=1)

# %%
y_pred3 = model3.predict(X_test_M3_full)

# %%
preproc.plot_forecasts("M3", y_test, y_pred3)

# %%
preproc.print_test_stats(y_test, y_pred3)
# Out:
# RMSE: 0.032
# MAE: 0.023
# R²: 0.998

# %% [markdown]
# # M4: Prophet

# %% [raw]
# Documentation:
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
# https://github.com/facebook/prophet/blob/main/notebooks/quick_start.ipynb

# %%
prophet_df = y_train.to_frame(name='y')
prophet_df = prophet_df.reset_index()  
prophet_df.columns = ['ds', 'y']

# %%
from prophet import Prophet

m = Prophet()
m.fit(prophet_df)
# Out:
# 12:02:25 - cmdstanpy - INFO - Chain [1] start processing
# 12:03:56 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = y_test.index.to_frame(name='ds')
future = future.reset_index()  
future = future.drop('datetime', axis = 1)

# %%
full_future = pd.concat([prophet_df['ds'], future])

# %%
forecast = m.predict(full_future)

# forecast.columns

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                         ds      yhat  yhat_lower  yhat_upper
# 280501 2024-12-31 21:30:00  0.039133   -1.802904    1.946465
# 280502 2024-12-31 22:00:00  0.059297   -1.844479    2.072062
# 280503 2024-12-31 22:30:00  0.069331   -1.886508    2.042361
# 280504 2024-12-31 23:00:00  0.068322   -1.897752    2.018673
# 280505 2024-12-31 23:30:00  0.056477   -1.847479    2.075715

# %% [markdown]
# ## Residuals

# %%
# Merge actuals and predictions
prophet_merged = prophet_df[['ds', 'y']].merge(forecast[['ds', 'yhat']], on='ds')
prophet_merged['residual'] = prophet_merged['y'] - prophet_merged['yhat']

# %%
prophet_merged.head()
# Out:
#                    ds         y      yhat  residual
# 0 2009-01-01 03:00:00  0.750925 -0.224681  0.975606
# 1 2009-01-01 03:30:00  0.665295 -0.267428  0.932723
# 2 2009-01-01 04:00:00  0.665295 -0.308866  0.974161
# 3 2009-01-01 04:30:00  0.665295 -0.347836  1.013131
# 4 2009-01-01 05:00:00  0.655780 -0.382824  1.038605

# %%
prophet_merged_train = prophet_merged.iloc[:len(y_train)]

# %%
plt.hist(prophet_merged_train.residual, bins = 40)
plt.title('Training Residuals')
plt.show()

# %%
# Checking for Heteroskedasticity

preproc.plot_variance(prophet_merged_train.yhat, prophet_merged_train.residual, bounds=False)

# %% [markdown]
# ## Evaluation

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
y_pred4 = forecast.yhat[-len(y_test):]

# %%
preproc.plot_forecasts("M4", y_test, y_pred4)

# %%
preproc.print_test_stats(y_test, y_pred4)
# Out:
# RMSE: 1.108
# MAE: 0.854
# R²: -1.145
