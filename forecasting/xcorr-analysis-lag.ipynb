# %% [markdown]
# # Cross-Correlation Analysis for Lag Time Distribution

# %%
import numpy as np
import pandas as pd
import dataretrieval.nwis as nwis
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
import math
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.graphics.tsaplots import plot_acf

# %%
int_freq = 30 #15

# %%
def deduplicate_data(df):

    # Remove data not on the int_freq min interval
    if int_freq == 15:
        df = df[df.index.minute.isin([0, 15, 30, 45]) & (df.index.second == 0) & (df.index.microsecond == 0)]
    if int_freq == 30:
        df = df[df.index.minute.isin([0, 30]) & (df.index.second == 0) & (df.index.microsecond == 0)]

    old_len = len(df)
    
    # Identify all duplicated rows based on the datetime index
    duplicate_rows = df[df.index.duplicated(keep=False)]  # keep=False keeps all copies
    
    # Extract unique dates (without time) from duplicated timestamps
    duplicate_dates = np.unique(duplicate_rows.index.date)
    
    # Print results
    print("Duplicate Dates:")
    for date in duplicate_dates:
        print(f"  - {date}")
    print("\nDuplicated Data:")
    print(duplicate_rows)

    # Remove duplicates
    df = df[~df.index.duplicated(keep='first')]

    new_len = len(df)
    removed_rows = old_len - new_len
    
    print(f"Removed {removed_rows} rows")
    print()
    
    return df

# %%
def drop_nan(df):
    before = len(df)
    df_cleaned = df.dropna(subset=['00065'])
    after = len(df_cleaned)
    removed = before - after
    print(f"Removed {removed} rows with NaN in '00065'")
    print()
    return df_cleaned

# %%
def impute_missing_data(df):

    freq=str(int_freq) + 'min'
    
    # Create full expected range at specified frequency
    full_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq=freq)

    # Find missing timestamps
    missing = full_range.difference(df.index)

    # Print missing days report
    missing_days = pd.Series(missing.date).unique()
    if len(missing_days) > 0:
        print("Missing data on the following days:")
        for day in missing_days:
            print(f"- {day}")
    else:
        print("No missing days.")

    imputed_count = 0

    # Impute missing values using average of the endpoints
    for missing_time in missing:
        # Find the two nearest data points surrounding the missing timestamp
        prev_point = df[df.index <= missing_time].iloc[-1:]  # Last point before the missing timestamp
        next_point = df[df.index > missing_time].iloc[:1]    # First point after the missing timestamp

        if not prev_point.empty and not next_point.empty:
            avg_value = (prev_point['00065'].values[0] + next_point['00065'].values[0]) / 2
            df.loc[missing_time] = avg_value
            imputed_count += 1
            print(f"Imputed missing data at {missing_time} with value {avg_value:.2f}")
        elif not prev_point.empty:
            df.loc[missing_time] = prev_point['00065'].values[0]
            imputed_count += 1
            print(f"Imputed missing data at {missing_time} with value {prev_point['00065'].values[0]:.2f}")
        elif not next_point.empty:
            df.loc[missing_time] = next_point['00065'].values[0]
            imputed_count += 1
            print(f"Imputed missing data at {missing_time} with value {next_point['00065'].values[0]:.2f}")
        else:
            print(f"Unable to impute missing data at {missing_time}.")

    print(f"\nImputed {imputed_count} rows")

    # Resort imputed data
    df = df.sort_index()

    return df

# %% [markdown]
# ## USGS Stream Gauge Data Collection & Preprocessing
# Reference: https://github.com/DOI-USGS/dataretrieval-python

# %%
start_date = '2009-01-01'
end_date = '2024-12-31'

start_date_obj = datetime.strptime(start_date, '%Y-%m-%d') 
start_new_format = start_date_obj.strftime('%m-%d-%Y') 
end_date_obj = datetime.strptime(end_date, '%Y-%m-%d') 
end_new_format = end_date_obj.strftime('%m-%d-%Y') 

date_range = start_new_format + ' to ' + end_new_format

# %% [markdown]
# ### Downstream Data (Inflow)

# %%
inflow_site = '14128600'
print(nwis.get_record(sites=inflow_site, service='site').station_nm[0])
# Out:
# COLUMBIA RIVER AT STEVENSON, WA

# %%
# Get instantaneous values (iv)
df = nwis.get_record(sites=inflow_site, service='iv', start=start_date, end=end_date)
df.index = df.index.tz_convert('America/Los_Angeles')  # Convert to Pacific Time
df.index = df.index.tz_localize(None) # Remove timezone info 
df = df[['site_no','00065']]

# Deduplicate data
df = deduplicate_data(df)

# Remove NaNs
df = drop_nan(df)

# Impute missing data
df = impute_missing_data(df)
# Out:
# Duplicate Dates:
#   - 2013-11-03
#   - 2014-11-02
#   - 2015-11-01
#   - 2016-11-06
#   - 2017-11-05
#   - 2018-11-04
#   - 2019-11-03
#   - 2020-11-01
#   - 2021-11-07
#   - 2022-11-06
#   - 2023-11-05
#   - 2024-11-03
#
# Duplicated Data:
#                       site_no  00065
# datetime
# 2013-11-03 01:00:00  14128600  75.59
# 2013-11-03 01:30:00  14128600  75.54
# 2013-11-03 01:00:00  14128600  75.47
# 2013-11-03 01:30:00  14128600  75.45
# 2014-11-02 01:00:00  14128600  75.65
# 2014-11-02 01:30:00  14128600  75.61
# 2014-11-02 01:00:00  14128600  75.57
# 2014-11-02 01:30:00  14128600  75.55
# 2015-11-01 01:00:00  14128600  73.53
# 2015-11-01 01:30:00  14128600  73.42
# 2015-11-01 01:00:00  14128600  73.34
# 2015-11-01 01:30:00  14128600  73.25
# 2016-11-06 01:00:00  14128600  73.45
# 2016-11-06 01:30:00  14128600  73.38
# 2016-11-06 01:00:00  14128600  73.33
# 2016-11-06 01:30:00  14128600  73.25
# 2017-11-05 01:00:00  14128600  75.22
# 2017-11-05 01:30:00  14128600  75.25
# 2017-11-05 01:00:00  14128600  75.17
# 2017-11-05 01:30:00  14128600  75.03
# 2018-11-04 01:00:00  14128600  74.73
# 2018-11-04 01:30:00  14128600  74.58
# 2018-11-04 01:00:00  14128600  74.47
# 2018-11-04 01:30:00  14128600  74.28
# 2019-11-03 01:00:00  14128600  74.49
# 2019-11-03 01:30:00  14128600  74.49
# 2019-11-03 01:00:00  14128600  74.50
# 2019-11-03 01:30:00  14128600  74.59
# 2020-11-01 01:00:00  14128600  75.08
# 2020-11-01 01:30:00  14128600  75.09
# 2020-11-01 01:00:00  14128600  75.13
# 2020-11-01 01:30:00  14128600  75.07
# 2021-11-07 01:00:00  14128600  76.56
# 2021-11-07 01:30:00  14128600  76.52
# 2021-11-07 01:00:00  14128600  76.54
# 2021-11-07 01:30:00  14128600  76.55
# 2022-11-06 01:00:00  14128600  75.31
# 2022-11-06 01:30:00  14128600  75.22
# 2022-11-06 01:00:00  14128600  75.05
# 2022-11-06 01:30:00  14128600  74.84
# 2023-11-05 01:00:00  14128600  75.84
# 2023-11-05 01:30:00  14128600  75.84
# 2023-11-05 01:00:00  14128600  75.76
# 2023-11-05 01:30:00  14128600  75.64
# 2024-11-03 01:00:00  14128600  76.08
# 2024-11-03 01:30:00  14128600  76.07
# 2024-11-03 01:00:00  14128600  76.02
# 2024-11-03 01:30:00  14128600  75.90
# Removed 24 rows
#
# Removed 0 rows with NaN in '00065'
#
# Missing data on the following days:
# - 2009-03-08
# - 2010-03-14
# - 2011-03-13
# - 2012-03-11
# - 2012-07-05
# - 2013-03-10
# - 2013-07-08
# - 2013-08-13
# - 2014-03-09
# - 2015-03-08
# - 2016-03-13
# - 2017-03-12
# - 2017-10-25
# - 2018-03-11
# - 2019-03-10
# - 2019-12-17
# - 2020-02-19
# - 2020-02-21
# - 2020-02-22
# - 2020-03-08
# - 2021-03-14
# - 2021-05-12
# - 2021-05-13
# - 2021-05-14
# - 2021-06-11
# - 2021-06-16
# - 2021-06-17
# - 2021-06-18
# - 2021-06-20
# - 2021-06-21
# - 2021-06-23
# - 2021-06-24
# - 2021-06-25
# - 2021-06-26
# - 2021-06-28
# - 2021-07-04
# - 2021-07-22
# - 2021-10-07
# - 2021-10-08
# - 2022-03-13
# - 2023-03-12
# - 2024-03-10
# Imputed missing data at 2009-03-08 02:00:00 with value 75.88
# Imputed missing data at 2009-03-08 02:30:00 with value 75.87
# Imputed missing data at 2010-03-14 02:00:00 with value 75.53
# Imputed missing data at 2010-03-14 02:30:00 with value 75.37
# Imputed missing data at 2010-03-14 04:00:00 with value 75.22
# Imputed missing data at 2010-03-14 04:30:00 with value 75.15
# Imputed missing data at 2010-03-14 05:00:00 with value 75.12
# Imputed missing data at 2011-03-13 02:00:00 with value 74.61
# Imputed missing data at 2011-03-13 02:30:00 with value 74.36
# Imputed missing data at 2012-03-11 02:00:00 with value 74.82
# Imputed missing data at 2012-03-11 02:30:00 with value 75.05
# Imputed missing data at 2012-07-05 15:00:00 with value 76.47
# Imputed missing data at 2013-03-10 02:00:00 with value 76.13
# Imputed missing data at 2013-03-10 02:30:00 with value 75.96
# Imputed missing data at 2013-07-08 09:30:00 with value 75.43
# Imputed missing data at 2013-07-08 10:00:00 with value 75.17
# Imputed missing data at 2013-08-13 16:30:00 with value 75.61
# Imputed missing data at 2013-08-13 17:00:00 with value 75.83
# Imputed missing data at 2013-08-13 17:30:00 with value 75.94
# Imputed missing data at 2014-03-09 02:00:00 with value 76.08
# Imputed missing data at 2014-03-09 02:30:00 with value 76.14
# Imputed missing data at 2015-03-08 02:00:00 with value 75.65
# Imputed missing data at 2015-03-08 02:30:00 with value 75.40
# Imputed missing data at 2016-03-13 02:00:00 with value 75.28
# Imputed missing data at 2016-03-13 02:30:00 with value 75.23
# Imputed missing data at 2017-03-12 02:00:00 with value 75.97
# Imputed missing data at 2017-03-12 02:30:00 with value 76.35
# Imputed missing data at 2017-10-25 15:30:00 with value 74.96
# Imputed missing data at 2018-03-11 02:00:00 with value 74.56
# Imputed missing data at 2018-03-11 02:30:00 with value 74.36
# Imputed missing data at 2019-03-10 02:00:00 with value 74.06
# Imputed missing data at 2019-03-10 02:30:00 with value 73.90
# Imputed missing data at 2019-12-17 09:30:00 with value 74.71
# Imputed missing data at 2019-12-17 10:00:00 with value 75.11
# Imputed missing data at 2019-12-17 10:30:00 with value 75.31
# Imputed missing data at 2019-12-17 11:00:00 with value 75.41
# Imputed missing data at 2019-12-17 11:30:00 with value 75.46
# Imputed missing data at 2019-12-17 12:00:00 with value 75.48
# Imputed missing data at 2019-12-17 12:30:00 with value 75.50
# Imputed missing data at 2019-12-17 13:00:00 with value 75.50
# Imputed missing data at 2020-02-19 08:00:00 with value 75.19
# Imputed missing data at 2020-02-19 08:30:00 with value 75.04
# Imputed missing data at 2020-02-19 23:00:00 with value 74.89
# Imputed missing data at 2020-02-19 23:30:00 with value 74.82
# Imputed missing data at 2020-02-21 08:00:00 with value 74.82
# Imputed missing data at 2020-02-21 08:30:00 with value 74.81
# Imputed missing data at 2020-02-22 07:00:00 with value 74.63
# Imputed missing data at 2020-02-22 07:30:00 with value 74.54
# Imputed missing data at 2020-03-08 02:00:00 with value 75.04
# Imputed missing data at 2020-03-08 02:30:00 with value 75.29
# Imputed missing data at 2021-03-14 02:00:00 with value 75.02
# Imputed missing data at 2021-03-14 02:30:00 with value 74.89
# Imputed missing data at 2021-05-12 16:30:00 with value 75.27
# Imputed missing data at 2021-05-12 17:00:00 with value 75.47
# Imputed missing data at 2021-05-12 17:30:00 with value 75.56
# Imputed missing data at 2021-05-12 18:00:00 with value 75.61
# Imputed missing data at 2021-05-12 18:30:00 with value 75.64
# Imputed missing data at 2021-05-12 19:00:00 with value 75.65
# Imputed missing data at 2021-05-12 19:30:00 with value 75.65
# Imputed missing data at 2021-05-12 20:00:00 with value 75.66
# Imputed missing data at 2021-05-12 20:30:00 with value 75.66
# Imputed missing data at 2021-05-12 21:00:00 with value 75.66
# Imputed missing data at 2021-05-12 21:30:00 with value 75.66
# Imputed missing data at 2021-05-12 22:00:00 with value 75.66
# Imputed missing data at 2021-05-12 22:30:00 with value 75.66
# Imputed missing data at 2021-05-12 23:00:00 with value 75.66
# Imputed missing data at 2021-05-12 23:30:00 with value 75.66
# Imputed missing data at 2021-05-13 00:00:00 with value 75.66
# Imputed missing data at 2021-05-13 00:30:00 with value 75.66
# Imputed missing data at 2021-05-13 01:00:00 with value 75.66
# Imputed missing data at 2021-05-13 01:30:00 with value 75.66
# Imputed missing data at 2021-05-13 02:00:00 with value 75.66
# Imputed missing data at 2021-05-13 02:30:00 with value 75.66
# Imputed missing data at 2021-05-13 03:00:00 with value 75.66
# Imputed missing data at 2021-05-13 03:30:00 with value 75.66
# Imputed missing data at 2021-05-13 04:00:00 with value 75.66
# Imputed missing data at 2021-05-13 04:30:00 with value 75.66
# Imputed missing data at 2021-05-13 05:00:00 with value 75.66
# Imputed missing data at 2021-05-13 05:30:00 with value 75.66
# Imputed missing data at 2021-05-13 06:00:00 with value 75.66
# Imputed missing data at 2021-05-13 06:30:00 with value 75.66
# Imputed missing data at 2021-05-13 07:00:00 with value 75.66
# Imputed missing data at 2021-05-13 07:30:00 with value 75.66
# Imputed missing data at 2021-05-13 08:00:00 with value 75.66
# Imputed missing data at 2021-05-13 08:30:00 with value 75.66
# Imputed missing data at 2021-05-13 09:00:00 with value 75.66
# Imputed missing data at 2021-05-13 09:30:00 with value 75.66
# Imputed missing data at 2021-05-13 10:00:00 with value 75.66
# Imputed missing data at 2021-05-13 10:30:00 with value 75.66
# Imputed missing data at 2021-05-13 11:00:00 with value 75.66
# Imputed missing data at 2021-05-13 11:30:00 with value 75.66
# Imputed missing data at 2021-05-13 12:00:00 with value 75.66
# Imputed missing data at 2021-05-13 12:30:00 with value 75.66
# Imputed missing data at 2021-05-13 13:00:00 with value 75.66
# Imputed missing data at 2021-05-13 13:30:00 with value 75.66
# Imputed missing data at 2021-05-13 14:00:00 with value 75.66
# Imputed missing data at 2021-05-13 14:30:00 with value 75.66
# Imputed missing data at 2021-05-13 15:00:00 with value 75.66
# Imputed missing data at 2021-05-13 15:30:00 with value 75.66
# Imputed missing data at 2021-05-13 16:00:00 with value 75.66
# Imputed missing data at 2021-05-13 16:30:00 with value 75.66
# Imputed missing data at 2021-05-13 17:00:00 with value 75.66
# Imputed missing data at 2021-05-13 17:30:00 with value 75.66
# Imputed missing data at 2021-05-13 18:00:00 with value 75.66
# Imputed missing data at 2021-05-13 18:30:00 with value 75.66
# Imputed missing data at 2021-05-13 19:00:00 with value 75.66
# Imputed missing data at 2021-05-13 19:30:00 with value 75.66
# Imputed missing data at 2021-05-13 20:00:00 with value 75.66
# Imputed missing data at 2021-05-13 20:30:00 with value 75.66
# Imputed missing data at 2021-05-13 21:00:00 with value 75.66
# Imputed missing data at 2021-05-13 21:30:00 with value 75.66
# Imputed missing data at 2021-05-13 22:00:00 with value 75.66
# Imputed missing data at 2021-05-13 22:30:00 with value 75.66
# Imputed missing data at 2021-05-13 23:00:00 with value 75.66
# Imputed missing data at 2021-05-13 23:30:00 with value 75.66
# Imputed missing data at 2021-05-14 00:00:00 with value 75.66
# Imputed missing data at 2021-05-14 00:30:00 with value 75.66
# Imputed missing data at 2021-05-14 01:00:00 with value 75.66
# Imputed missing data at 2021-05-14 01:30:00 with value 75.66
# Imputed missing data at 2021-05-14 02:00:00 with value 75.66
# Imputed missing data at 2021-05-14 02:30:00 with value 75.66
# Imputed missing data at 2021-05-14 03:00:00 with value 75.66
# Imputed missing data at 2021-05-14 03:30:00 with value 75.66
# Imputed missing data at 2021-05-14 04:00:00 with value 75.66
# Imputed missing data at 2021-05-14 04:30:00 with value 75.66
# Imputed missing data at 2021-05-14 05:00:00 with value 75.66
# Imputed missing data at 2021-05-14 05:30:00 with value 75.66
# Imputed missing data at 2021-05-14 06:00:00 with value 75.66
# Imputed missing data at 2021-05-14 06:30:00 with value 75.66
# Imputed missing data at 2021-05-14 07:00:00 with value 75.66
# Imputed missing data at 2021-05-14 07:30:00 with value 75.66
# Imputed missing data at 2021-05-14 08:00:00 with value 75.66
# Imputed missing data at 2021-05-14 08:30:00 with value 75.66
# Imputed missing data at 2021-05-14 09:00:00 with value 75.66
# Imputed missing data at 2021-05-14 09:30:00 with value 75.66
# Imputed missing data at 2021-05-14 10:00:00 with value 75.66
# Imputed missing data at 2021-05-14 10:30:00 with value 75.66
# Imputed missing data at 2021-05-14 11:00:00 with value 75.66
# Imputed missing data at 2021-05-14 11:30:00 with value 75.66
# Imputed missing data at 2021-05-14 12:00:00 with value 75.66
# Imputed missing data at 2021-05-14 12:30:00 with value 75.66
# Imputed missing data at 2021-05-14 13:00:00 with value 75.66
# Imputed missing data at 2021-05-14 13:30:00 with value 75.66
# Imputed missing data at 2021-05-14 14:00:00 with value 75.66
# Imputed missing data at 2021-05-14 14:30:00 with value 75.66
# Imputed missing data at 2021-05-14 15:00:00 with value 75.66
# Imputed missing data at 2021-05-14 15:30:00 with value 75.66
# Imputed missing data at 2021-05-14 16:00:00 with value 75.66
# Imputed missing data at 2021-05-14 16:30:00 with value 75.66
# Imputed missing data at 2021-05-14 17:00:00 with value 75.66
# Imputed missing data at 2021-06-11 07:00:00 with value 75.51
# Imputed missing data at 2021-06-11 07:30:00 with value 75.44
# Imputed missing data at 2021-06-11 08:00:00 with value 75.40
# Imputed missing data at 2021-06-11 08:30:00 with value 75.38
# Imputed missing data at 2021-06-11 09:00:00 with value 75.37
# Imputed missing data at 2021-06-11 09:30:00 with value 75.36
# Imputed missing data at 2021-06-11 10:00:00 with value 75.36
# Imputed missing data at 2021-06-11 10:30:00 with value 75.36
# Imputed missing data at 2021-06-11 11:00:00 with value 75.36
# Imputed missing data at 2021-06-11 18:00:00 with value 75.44
# Imputed missing data at 2021-06-16 15:00:00 with value 75.41
# Imputed missing data at 2021-06-17 11:00:00 with value 75.38
# Imputed missing data at 2021-06-17 12:00:00 with value 75.43
# Imputed missing data at 2021-06-17 13:00:00 with value 75.48
# Imputed missing data at 2021-06-17 14:00:00 with value 75.51
# Imputed missing data at 2021-06-17 18:00:00 with value 75.58
# Imputed missing data at 2021-06-18 08:00:00 with value 75.41
# Imputed missing data at 2021-06-18 12:00:00 with value 75.23
# Imputed missing data at 2021-06-18 14:00:00 with value 75.24
# Imputed missing data at 2021-06-18 18:00:00 with value 75.25
# Imputed missing data at 2021-06-20 14:30:00 with value 75.45
# Imputed missing data at 2021-06-20 17:00:00 with value 75.59
# Imputed missing data at 2021-06-21 18:00:00 with value 75.49
# Imputed missing data at 2021-06-23 13:00:00 with value 75.56
# Imputed missing data at 2021-06-23 17:00:00 with value 75.68
# Imputed missing data at 2021-06-23 18:00:00 with value 75.79
# Imputed missing data at 2021-06-24 08:00:00 with value 75.57
# Imputed missing data at 2021-06-24 13:00:00 with value 75.61
# Imputed missing data at 2021-06-24 14:00:00 with value 75.69
# Imputed missing data at 2021-06-24 18:00:00 with value 75.75
# Imputed missing data at 2021-06-25 08:00:00 with value 75.47
# Imputed missing data at 2021-06-25 15:00:00 with value 75.28
# Imputed missing data at 2021-06-25 17:30:00 with value 75.21
# Imputed missing data at 2021-06-25 18:00:00 with value 75.18
# Imputed missing data at 2021-06-26 03:00:00 with value 75.34
# Imputed missing data at 2021-06-26 07:00:00 with value 75.37
# Imputed missing data at 2021-06-26 14:00:00 with value 75.39
# Imputed missing data at 2021-06-26 18:00:00 with value 75.44
# Imputed missing data at 2021-06-28 15:00:00 with value 75.64
# Imputed missing data at 2021-07-04 06:00:00 with value 75.62
# Imputed missing data at 2021-07-22 09:00:00 with value 75.32
# Imputed missing data at 2021-07-22 11:00:00 with value 75.17
# Imputed missing data at 2021-07-22 14:00:00 with value 75.11
# Imputed missing data at 2021-10-07 18:00:00 with value 75.21
# Imputed missing data at 2021-10-08 06:00:00 with value 75.39
# Imputed missing data at 2022-03-13 02:00:00 with value 75.24
# Imputed missing data at 2022-03-13 02:30:00 with value 75.17
# Imputed missing data at 2023-03-12 02:00:00 with value 75.43
# Imputed missing data at 2023-03-12 02:30:00 with value 75.56
# Imputed missing data at 2024-03-10 02:00:00 with value 75.06
# Imputed missing data at 2024-03-10 02:30:00 with value 74.81
#
# Imputed 201 rows

# %% [markdown]
# ### Upstream Data (Outflow)

# %%
outflow_site = '14105700'
print(nwis.get_record(sites=outflow_site, service='site').station_nm[0])
# Out:
# COLUMBIA RIVER AT THE DALLES, OR

# %%
# Get instantaneous values (iv)
df2 = nwis.get_record(sites=outflow_site, service='iv', start=start_date, end=end_date)
df2.index = df2.index.tz_convert('America/Los_Angeles')  # Convert to Pacific Time
df2.index = df2.index.tz_localize(None) # Remove timezone info 
df2 = df2[['site_no','00065']]

# Deduplicate data
df2 = deduplicate_data(df2)

# Remove NaNs
df2 = drop_nan(df2)

# Impute missing data
df2 = impute_missing_data(df2)
# Out:
# Duplicate Dates:
#   - 2009-11-01
#   - 2010-11-07
#   - 2011-11-06
#   - 2012-11-04
#   - 2013-11-03
#   - 2014-11-02
#   - 2015-11-01
#   - 2016-11-06
#   - 2017-11-05
#   - 2018-11-04
#   - 2019-11-03
#   - 2020-11-01
#   - 2021-11-07
#   - 2022-11-06
#   - 2023-11-05
#   - 2024-11-03
#
# Duplicated Data:
#                       site_no  00065
# datetime
# 2009-11-01 01:00:00  14105700  77.60
# 2009-11-01 01:30:00  14105700  77.71
# 2009-11-01 01:00:00  14105700  77.62
# 2009-11-01 01:30:00  14105700  77.54
# 2010-11-07 01:00:00  14105700  76.83
# ...                       ...    ...
# 2023-11-05 01:30:00  14105700  75.89
# 2024-11-03 01:00:00  14105700  76.40
# 2024-11-03 01:30:00  14105700  76.39
# 2024-11-03 01:00:00  14105700  76.27
# 2024-11-03 01:30:00  14105700  76.24
#
# [64 rows x 2 columns]
# Removed 32 rows
#
# Removed 437 rows with NaN in '00065'
#
# Missing data on the following days:
# - 2009-01-26
# - 2009-01-31
# - 2009-02-03
# - 2009-02-04
# - 2009-02-07
# - 2009-02-10
# - 2009-02-11
# - 2009-02-15
# - 2009-02-22
# - 2009-02-25
# - 2009-03-02
# - 2009-03-04
# - 2009-03-08
# - 2009-03-25
# - 2009-03-26
# - 2009-03-27
# - 2009-03-28
# - 2009-03-29
# - 2009-03-30
# - 2009-03-31
# - 2009-04-01
# - 2009-04-02
# - 2009-06-29
# - 2009-10-05
# - 2009-11-04
# - 2010-03-14
# - 2010-05-18
# - 2011-03-13
# - 2012-03-11
# - 2012-10-17
# - 2013-03-10
# - 2013-06-05
# - 2013-06-14
# - 2013-09-19
# - 2013-11-26
# - 2014-03-09
# - 2014-05-13
# - 2014-06-09
# - 2014-06-10
# - 2014-06-11
# - 2014-07-24
# - 2014-10-16
# - 2014-10-17
# - 2015-03-08
# - 2015-03-26
# - 2016-03-13
# - 2016-10-01
# - 2016-10-02
# - 2016-10-03
# - 2016-10-04
# - 2017-03-12
# - 2017-06-15
# - 2018-03-11
# - 2018-03-15
# - 2019-03-10
# - 2019-10-09
# - 2020-03-08
# - 2021-03-14
# - 2022-03-13
# - 2023-03-12
# - 2023-05-03
# - 2023-10-25
# - 2024-03-10
# - 2024-03-18
# - 2024-03-29
# - 2024-04-02
# - 2024-05-09
# - 2024-09-09
# - 2024-09-19
# - 2024-10-29
# - 2024-10-30
# - 2024-10-31
# - 2024-11-01
# - 2024-11-02
# - 2024-11-03
# - 2024-11-04
# - 2024-11-05
# - 2024-11-06
# - 2024-11-07
# - 2024-11-08
# - 2024-11-09
# - 2024-11-10
# - 2024-11-11
# - 2024-11-12
# - 2024-11-13
# Imputed missing data at 2009-01-26 04:00:00 with value 73.95
# Imputed missing data at 2009-01-31 20:00:00 with value 75.30
# Imputed missing data at 2009-02-03 04:00:00 with value 75.35
# Imputed missing data at 2009-02-03 20:00:00 with value 75.36
# Imputed missing data at 2009-02-04 20:00:00 with value 75.66
# Imputed missing data at 2009-02-07 04:00:00 with value 75.35
# Imputed missing data at 2009-02-10 20:00:00 with value 75.89
# Imputed missing data at 2009-02-11 20:00:00 with value 76.64
# Imputed missing data at 2009-02-15 04:00:00 with value 76.11
# Imputed missing data at 2009-02-22 04:00:00 with value 75.55
# Imputed missing data at 2009-02-25 20:00:00 with value 75.87
# Imputed missing data at 2009-03-02 04:00:00 with value 75.79
# Imputed missing data at 2009-03-02 20:00:00 with value 76.16
# Imputed missing data at 2009-03-04 20:00:00 with value 76.67
# Imputed missing data at 2009-03-08 02:00:00 with value 76.54
# Imputed missing data at 2009-03-08 02:30:00 with value 76.48
# Imputed missing data at 2009-03-25 00:00:00 with value 76.92
# Imputed missing data at 2009-03-25 00:30:00 with value 77.13
# Imputed missing data at 2009-03-25 01:00:00 with value 77.24
# Imputed missing data at 2009-03-25 01:30:00 with value 77.30
# Imputed missing data at 2009-03-25 02:00:00 with value 77.32
# Imputed missing data at 2009-03-25 02:30:00 with value 77.34
# Imputed missing data at 2009-03-25 03:00:00 with value 77.34
# Imputed missing data at 2009-03-25 03:30:00 with value 77.35
# Imputed missing data at 2009-03-25 04:00:00 with value 77.35
# Imputed missing data at 2009-03-25 04:30:00 with value 77.35
# Imputed missing data at 2009-03-25 05:00:00 with value 77.35
# Imputed missing data at 2009-03-25 05:30:00 with value 77.35
# Imputed missing data at 2009-03-25 06:00:00 with value 77.35
# Imputed missing data at 2009-03-25 06:30:00 with value 77.35
# Imputed missing data at 2009-03-25 07:00:00 with value 77.35
# Imputed missing data at 2009-03-25 07:30:00 with value 77.35
# Imputed missing data at 2009-03-25 08:00:00 with value 77.35
# Imputed missing data at 2009-03-25 08:30:00 with value 77.35
# Imputed missing data at 2009-03-25 09:00:00 with value 77.35
# Imputed missing data at 2009-03-25 09:30:00 with value 77.35
# Imputed missing data at 2009-03-25 10:00:00 with value 77.35
# Imputed missing data at 2009-03-25 10:30:00 with value 77.35
# Imputed missing data at 2009-03-25 11:00:00 with value 77.35
# Imputed missing data at 2009-03-25 11:30:00 with value 77.35
# Imputed missing data at 2009-03-25 12:00:00 with value 77.35
# Imputed missing data at 2009-03-25 12:30:00 with value 77.35
# Imputed missing data at 2009-03-25 13:00:00 with value 77.35
# Imputed missing data at 2009-03-25 13:30:00 with value 77.35
# Imputed missing data at 2009-03-25 14:00:00 with value 77.35
# Imputed missing data at 2009-03-25 14:30:00 with value 77.35
# Imputed missing data at 2009-03-25 15:00:00 with value 77.35
# Imputed missing data at 2009-03-25 15:30:00 with value 77.35
# Imputed missing data at 2009-03-25 16:00:00 with value 77.35
# Imputed missing data at 2009-03-25 16:30:00 with value 77.35
# Imputed missing data at 2009-03-25 17:00:00 with value 77.35
# Imputed missing data at 2009-03-25 17:30:00 with value 77.35
# Imputed missing data at 2009-03-25 18:00:00 with value 77.35
# Imputed missing data at 2009-03-25 18:30:00 with value 77.35
# Imputed missing data at 2009-03-25 19:00:00 with value 77.35
# Imputed missing data at 2009-03-25 19:30:00 with value 77.35
# Imputed missing data at 2009-03-25 20:00:00 with value 77.35
# Imputed missing data at 2009-03-25 20:30:00 with value 77.35
# Imputed missing data at 2009-03-25 21:00:00 with value 77.35
# Imputed missing data at 2009-03-25 21:30:00 with value 77.35
# Imputed missing data at 2009-03-25 22:00:00 with value 77.35
# Imputed missing data at 2009-03-25 22:30:00 with value 77.35
# Imputed missing data at 2009-03-25 23:00:00 with value 77.35
# Imputed missing data at 2009-03-25 23:30:00 with value 77.35
# Imputed missing data at 2009-03-26 09:00:00 with value 77.25
# Imputed missing data at 2009-03-26 09:30:00 with value 77.20
# Imputed missing data at 2009-03-26 10:00:00 with value 77.18
# Imputed missing data at 2009-03-26 10:30:00 with value 77.16
# Imputed missing data at 2009-03-26 11:00:00 with value 77.16
# Imputed missing data at 2009-03-26 11:30:00 with value 77.15
# Imputed missing data at 2009-03-26 12:00:00 with value 77.15
# Imputed missing data at 2009-03-26 12:30:00 with value 77.15
# Imputed missing data at 2009-03-26 13:00:00 with value 77.15
# Imputed missing data at 2009-03-26 13:30:00 with value 77.15
# Imputed missing data at 2009-03-26 14:00:00 with value 77.15
# Imputed missing data at 2009-03-26 14:30:00 with value 77.15
# Imputed missing data at 2009-03-26 15:00:00 with value 77.15
# Imputed missing data at 2009-03-27 00:00:00 with value 77.44
# Imputed missing data at 2009-03-27 00:30:00 with value 77.59
# Imputed missing data at 2009-03-27 01:00:00 with value 77.66
# Imputed missing data at 2009-03-27 01:30:00 with value 77.69
# Imputed missing data at 2009-03-27 02:00:00 with value 77.71
# Imputed missing data at 2009-03-27 02:30:00 with value 77.72
# Imputed missing data at 2009-03-27 03:00:00 with value 77.73
# Imputed missing data at 2009-03-27 03:30:00 with value 77.73
# Imputed missing data at 2009-03-27 04:00:00 with value 77.73
# Imputed missing data at 2009-03-27 04:30:00 with value 77.73
# Imputed missing data at 2009-03-27 05:00:00 with value 77.73
# Imputed missing data at 2009-03-27 05:30:00 with value 77.73
# Imputed missing data at 2009-03-27 06:00:00 with value 77.73
# Imputed missing data at 2009-03-27 06:30:00 with value 77.73
# Imputed missing data at 2009-03-27 07:00:00 with value 77.73
# Imputed missing data at 2009-03-27 07:30:00 with value 77.73
# Imputed missing data at 2009-03-27 08:00:00 with value 77.73
# Imputed missing data at 2009-03-27 08:30:00 with value 77.73
# Imputed missing data at 2009-03-27 09:00:00 with value 77.73
# Imputed missing data at 2009-03-27 09:30:00 with value 77.73
# Imputed missing data at 2009-03-27 10:00:00 with value 77.73
# Imputed missing data at 2009-03-27 10:30:00 with value 77.73
# Imputed missing data at 2009-03-27 11:00:00 with value 77.73
# Imputed missing data at 2009-03-27 11:30:00 with value 77.73
# Imputed missing data at 2009-03-27 12:00:00 with value 77.73
# Imputed missing data at 2009-03-27 12:30:00 with value 77.73
# Imputed missing data at 2009-03-27 13:00:00 with value 77.73
# Imputed missing data at 2009-03-27 13:30:00 with value 77.73
# Imputed missing data at 2009-03-27 14:00:00 with value 77.73
# Imputed missing data at 2009-03-27 14:30:00 with value 77.73
# Imputed missing data at 2009-03-27 15:00:00 with value 77.73
# Imputed missing data at 2009-03-27 15:30:00 with value 77.73
# Imputed missing data at 2009-03-27 16:00:00 with value 77.73
# Imputed missing data at 2009-03-27 16:30:00 with value 77.73
# Imputed missing data at 2009-03-27 17:00:00 with value 77.73
# Imputed missing data at 2009-03-27 17:30:00 with value 77.73
# Imputed missing data at 2009-03-27 18:00:00 with value 77.73
# Imputed missing data at 2009-03-27 18:30:00 with value 77.73
# Imputed missing data at 2009-03-27 19:00:00 with value 77.73
# Imputed missing data at 2009-03-27 19:30:00 with value 77.73
# Imputed missing data at 2009-03-27 20:00:00 with value 77.73
# Imputed missing data at 2009-03-27 20:30:00 with value 77.73
# Imputed missing data at 2009-03-27 21:00:00 with value 77.73
# Imputed missing data at 2009-03-27 21:30:00 with value 77.73
# Imputed missing data at 2009-03-27 22:00:00 with value 77.73
# Imputed missing data at 2009-03-27 22:30:00 with value 77.73
# Imputed missing data at 2009-03-27 23:00:00 with value 77.73
# Imputed missing data at 2009-03-27 23:30:00 with value 77.73
# Imputed missing data at 2009-03-28 00:00:00 with value 77.73
# Imputed missing data at 2009-03-28 00:30:00 with value 77.73
# Imputed missing data at 2009-03-28 01:00:00 with value 77.73
# Imputed missing data at 2009-03-28 01:30:00 with value 77.73
# Imputed missing data at 2009-03-28 02:00:00 with value 77.73
# Imputed missing data at 2009-03-28 02:30:00 with value 77.73
# Imputed missing data at 2009-03-28 03:00:00 with value 77.73
# Imputed missing data at 2009-03-28 03:30:00 with value 77.73
# Imputed missing data at 2009-03-28 04:00:00 with value 77.73
# Imputed missing data at 2009-03-28 04:30:00 with value 77.73
# Imputed missing data at 2009-03-28 05:00:00 with value 77.73
# Imputed missing data at 2009-03-28 05:30:00 with value 77.73
# Imputed missing data at 2009-03-28 06:00:00 with value 77.73
# Imputed missing data at 2009-03-28 06:30:00 with value 77.73
# Imputed missing data at 2009-03-28 07:00:00 with value 77.73
# Imputed missing data at 2009-03-28 07:30:00 with value 77.73
# Imputed missing data at 2009-03-28 08:00:00 with value 77.73
# Imputed missing data at 2009-03-28 08:30:00 with value 77.73
# Imputed missing data at 2009-03-28 09:00:00 with value 77.73
# Imputed missing data at 2009-03-28 09:30:00 with value 77.73
# Imputed missing data at 2009-03-28 10:00:00 with value 77.73
# Imputed missing data at 2009-03-28 10:30:00 with value 77.73
# Imputed missing data at 2009-03-28 11:00:00 with value 77.73
# Imputed missing data at 2009-03-28 11:30:00 with value 77.73
# Imputed missing data at 2009-03-28 12:00:00 with value 77.73
# Imputed missing data at 2009-03-28 12:30:00 with value 77.73
# Imputed missing data at 2009-03-28 13:00:00 with value 77.73
# Imputed missing data at 2009-03-28 13:30:00 with value 77.73
# Imputed missing data at 2009-03-28 14:00:00 with value 77.73
# Imputed missing data at 2009-03-28 14:30:00 with value 77.73
# Imputed missing data at 2009-03-28 15:00:00 with value 77.73
# Imputed missing data at 2009-03-28 15:30:00 with value 77.73
# Imputed missing data at 2009-03-28 16:00:00 with value 77.73
# Imputed missing data at 2009-03-28 16:30:00 with value 77.73
# Imputed missing data at 2009-03-28 17:00:00 with value 77.73
# Imputed missing data at 2009-03-28 17:30:00 with value 77.73
# Imputed missing data at 2009-03-28 18:00:00 with value 77.73
# Imputed missing data at 2009-03-28 18:30:00 with value 77.73
# Imputed missing data at 2009-03-28 19:00:00 with value 77.73
# Imputed missing data at 2009-03-28 19:30:00 with value 77.73
# Imputed missing data at 2009-03-28 20:00:00 with value 77.73
# Imputed missing data at 2009-03-28 20:30:00 with value 77.73
# Imputed missing data at 2009-03-28 21:00:00 with value 77.73
# Imputed missing data at 2009-03-28 21:30:00 with value 77.73
# Imputed missing data at 2009-03-28 22:00:00 with value 77.73
# Imputed missing data at 2009-03-28 22:30:00 with value 77.73
# Imputed missing data at 2009-03-28 23:00:00 with value 77.73
# Imputed missing data at 2009-03-28 23:30:00 with value 77.73
# Imputed missing data at 2009-03-29 00:00:00 with value 77.73
# Imputed missing data at 2009-03-29 00:30:00 with value 77.73
# Imputed missing data at 2009-03-29 01:00:00 with value 77.73
# Imputed missing data at 2009-03-29 01:30:00 with value 77.73
# Imputed missing data at 2009-03-29 02:00:00 with value 77.73
# Imputed missing data at 2009-03-29 02:30:00 with value 77.73
# Imputed missing data at 2009-03-29 03:00:00 with value 77.73
# Imputed missing data at 2009-03-29 03:30:00 with value 77.73
# Imputed missing data at 2009-03-29 04:00:00 with value 77.73
# Imputed missing data at 2009-03-29 04:30:00 with value 77.73
# Imputed missing data at 2009-03-29 05:00:00 with value 77.73
# Imputed missing data at 2009-03-29 05:30:00 with value 77.73
# Imputed missing data at 2009-03-29 06:00:00 with value 77.73
# Imputed missing data at 2009-03-29 06:30:00 with value 77.73
# Imputed missing data at 2009-03-29 07:00:00 with value 77.73
# Imputed missing data at 2009-03-29 07:30:00 with value 77.73
# Imputed missing data at 2009-03-29 08:00:00 with value 77.73
# Imputed missing data at 2009-03-29 08:30:00 with value 77.73
# Imputed missing data at 2009-03-29 09:00:00 with value 77.73
# Imputed missing data at 2009-03-29 09:30:00 with value 77.73
# Imputed missing data at 2009-03-29 10:00:00 with value 77.73
# Imputed missing data at 2009-03-29 10:30:00 with value 77.73
# Imputed missing data at 2009-03-29 11:00:00 with value 77.73
# Imputed missing data at 2009-03-29 11:30:00 with value 77.73
# Imputed missing data at 2009-03-29 12:00:00 with value 77.73
# Imputed missing data at 2009-03-29 12:30:00 with value 77.73
# Imputed missing data at 2009-03-29 13:00:00 with value 77.73
# Imputed missing data at 2009-03-29 13:30:00 with value 77.73
# Imputed missing data at 2009-03-29 14:00:00 with value 77.73
# Imputed missing data at 2009-03-29 14:30:00 with value 77.73
# Imputed missing data at 2009-03-29 15:00:00 with value 77.73
# Imputed missing data at 2009-03-29 15:30:00 with value 77.73
# Imputed missing data at 2009-03-29 16:00:00 with value 77.73
# Imputed missing data at 2009-03-29 16:30:00 with value 77.73
# Imputed missing data at 2009-03-29 17:00:00 with value 77.73
# Imputed missing data at 2009-03-29 17:30:00 with value 77.73
# Imputed missing data at 2009-03-29 18:00:00 with value 77.73
# Imputed missing data at 2009-03-29 18:30:00 with value 77.73
# Imputed missing data at 2009-03-29 19:00:00 with value 77.73
# Imputed missing data at 2009-03-29 19:30:00 with value 77.73
# Imputed missing data at 2009-03-29 20:00:00 with value 77.73
# Imputed missing data at 2009-03-29 20:30:00 with value 77.73
# Imputed missing data at 2009-03-29 21:00:00 with value 77.73
# Imputed missing data at 2009-03-29 21:30:00 with value 77.73
# Imputed missing data at 2009-03-29 22:00:00 with value 77.73
# Imputed missing data at 2009-03-29 22:30:00 with value 77.73
# Imputed missing data at 2009-03-29 23:00:00 with value 77.73
# Imputed missing data at 2009-03-29 23:30:00 with value 77.73
# Imputed missing data at 2009-03-30 00:00:00 with value 77.73
# Imputed missing data at 2009-03-30 00:30:00 with value 77.73
# Imputed missing data at 2009-03-30 01:00:00 with value 77.73
# Imputed missing data at 2009-03-30 01:30:00 with value 77.73
# Imputed missing data at 2009-03-30 02:00:00 with value 77.73
# Imputed missing data at 2009-03-30 02:30:00 with value 77.73
# Imputed missing data at 2009-03-30 03:00:00 with value 77.73
# Imputed missing data at 2009-03-30 03:30:00 with value 77.73
# Imputed missing data at 2009-03-30 04:00:00 with value 77.73
# Imputed missing data at 2009-03-30 04:30:00 with value 77.73
# Imputed missing data at 2009-03-30 05:00:00 with value 77.73
# Imputed missing data at 2009-03-30 05:30:00 with value 77.73
# Imputed missing data at 2009-03-30 06:00:00 with value 77.73
# Imputed missing data at 2009-03-30 06:30:00 with value 77.73
# Imputed missing data at 2009-03-30 07:00:00 with value 77.73
# Imputed missing data at 2009-03-30 07:30:00 with value 77.73
# Imputed missing data at 2009-03-30 08:00:00 with value 77.73
# Imputed missing data at 2009-03-30 08:30:00 with value 77.73
# Imputed missing data at 2009-03-30 09:00:00 with value 77.73
# Imputed missing data at 2009-03-30 09:30:00 with value 77.73
# Imputed missing data at 2009-03-30 10:00:00 with value 77.73
# Imputed missing data at 2009-03-30 10:30:00 with value 77.73
# Imputed missing data at 2009-03-30 11:00:00 with value 77.73
# Imputed missing data at 2009-03-30 11:30:00 with value 77.73
# Imputed missing data at 2009-03-30 12:00:00 with value 77.73
# Imputed missing data at 2009-03-30 12:30:00 with value 77.73
# Imputed missing data at 2009-03-30 13:00:00 with value 77.73
# Imputed missing data at 2009-03-30 13:30:00 with value 77.73
# Imputed missing data at 2009-03-30 14:00:00 with value 77.73
# Imputed missing data at 2009-03-30 14:30:00 with value 77.73
# Imputed missing data at 2009-03-30 15:00:00 with value 77.73
# Imputed missing data at 2009-03-30 15:30:00 with value 77.73
# Imputed missing data at 2009-03-30 16:00:00 with value 77.73
# Imputed missing data at 2009-03-30 16:30:00 with value 77.73
# Imputed missing data at 2009-03-30 17:00:00 with value 77.73
# Imputed missing data at 2009-03-30 17:30:00 with value 77.73
# Imputed missing data at 2009-03-30 18:00:00 with value 77.73
# Imputed missing data at 2009-03-30 18:30:00 with value 77.73
# Imputed missing data at 2009-03-30 19:00:00 with value 77.73
# Imputed missing data at 2009-03-30 19:30:00 with value 77.73
# Imputed missing data at 2009-03-30 20:00:00 with value 77.73
# Imputed missing data at 2009-03-30 20:30:00 with value 77.73
# Imputed missing data at 2009-03-30 21:00:00 with value 77.73
# Imputed missing data at 2009-03-30 21:30:00 with value 77.73
# Imputed missing data at 2009-03-30 22:00:00 with value 77.73
# Imputed missing data at 2009-03-30 22:30:00 with value 77.73
# Imputed missing data at 2009-03-30 23:00:00 with value 77.73
# Imputed missing data at 2009-03-30 23:30:00 with value 77.73
# Imputed missing data at 2009-03-31 00:30:00 with value 77.62
# Imputed missing data at 2009-03-31 01:00:00 with value 77.56
# Imputed missing data at 2009-03-31 01:30:00 with value 77.54
# Imputed missing data at 2009-03-31 02:00:00 with value 77.52
# Imputed missing data at 2009-03-31 02:30:00 with value 77.52
# Imputed missing data at 2009-03-31 03:00:00 with value 77.51
# Imputed missing data at 2009-03-31 03:30:00 with value 77.51
# Imputed missing data at 2009-03-31 04:00:00 with value 77.51
# Imputed missing data at 2009-03-31 04:30:00 with value 77.51
# Imputed missing data at 2009-03-31 05:00:00 with value 77.51
# Imputed missing data at 2009-03-31 05:30:00 with value 77.51
# Imputed missing data at 2009-03-31 06:00:00 with value 77.51
# Imputed missing data at 2009-03-31 06:30:00 with value 77.51
# Imputed missing data at 2009-03-31 11:00:00 with value 77.79
# Imputed missing data at 2009-03-31 11:30:00 with value 77.92
# Imputed missing data at 2009-03-31 12:00:00 with value 77.99
# Imputed missing data at 2009-03-31 12:30:00 with value 78.03
# Imputed missing data at 2009-03-31 22:00:00 with value 77.52
# Imputed missing data at 2009-03-31 22:30:00 with value 77.27
# Imputed missing data at 2009-03-31 23:00:00 with value 77.15
# Imputed missing data at 2009-03-31 23:30:00 with value 77.08
# Imputed missing data at 2009-04-01 00:30:00 with value 76.93
# Imputed missing data at 2009-04-01 01:00:00 with value 76.86
# Imputed missing data at 2009-04-01 01:30:00 with value 76.82
# Imputed missing data at 2009-04-01 02:00:00 with value 76.80
# Imputed missing data at 2009-04-01 02:30:00 with value 76.79
# Imputed missing data at 2009-04-01 03:00:00 with value 76.78
# Imputed missing data at 2009-04-01 03:30:00 with value 76.78
# Imputed missing data at 2009-04-01 04:00:00 with value 76.78
# Imputed missing data at 2009-04-01 04:30:00 with value 76.78
# Imputed missing data at 2009-04-01 14:00:00 with value 77.22
# Imputed missing data at 2009-04-01 14:30:00 with value 77.44
# Imputed missing data at 2009-04-01 15:00:00 with value 77.55
# Imputed missing data at 2009-04-01 15:30:00 with value 77.61
# Imputed missing data at 2009-04-01 16:00:00 with value 77.63
# Imputed missing data at 2009-04-01 16:30:00 with value 77.65
# Imputed missing data at 2009-04-01 17:00:00 with value 77.65
# Imputed missing data at 2009-04-01 17:30:00 with value 77.66
# Imputed missing data at 2009-04-01 18:00:00 with value 77.66
# Imputed missing data at 2009-04-01 18:30:00 with value 77.66
# Imputed missing data at 2009-04-01 19:00:00 with value 77.66
# Imputed missing data at 2009-04-01 19:30:00 with value 77.66
# Imputed missing data at 2009-04-01 20:00:00 with value 77.66
# Imputed missing data at 2009-04-01 20:30:00 with value 77.66
# Imputed missing data at 2009-04-02 06:00:00 with value 77.39
# Imputed missing data at 2009-04-02 06:30:00 with value 77.26
# Imputed missing data at 2009-04-02 07:00:00 with value 77.20
# Imputed missing data at 2009-04-02 07:30:00 with value 77.16
# Imputed missing data at 2009-04-02 08:00:00 with value 77.15
# Imputed missing data at 2009-04-02 08:30:00 with value 77.14
# Imputed missing data at 2009-04-02 09:00:00 with value 77.13
# Imputed missing data at 2009-04-02 09:30:00 with value 77.13
# Imputed missing data at 2009-04-02 10:00:00 with value 77.13
# Imputed missing data at 2009-04-02 10:30:00 with value 77.13
# Imputed missing data at 2009-04-02 11:00:00 with value 77.13
# Imputed missing data at 2009-06-29 14:30:00 with value 77.73
# Imputed missing data at 2009-10-05 11:00:00 with value 77.84
# Imputed missing data at 2009-10-05 11:30:00 with value 77.90
# Imputed missing data at 2009-10-05 12:00:00 with value 77.92
# Imputed missing data at 2009-10-05 13:30:00 with value 77.95
# Imputed missing data at 2009-10-05 14:00:00 with value 77.97
# Imputed missing data at 2009-11-04 14:00:00 with value 78.10
# Imputed missing data at 2009-11-04 14:30:00 with value 78.17
# Imputed missing data at 2010-03-14 02:00:00 with value 76.96
# Imputed missing data at 2010-03-14 02:30:00 with value 76.35
# Imputed missing data at 2010-05-18 11:00:00 with value 76.94
# Imputed missing data at 2010-05-18 14:00:00 with value 77.32
# Imputed missing data at 2011-03-13 02:00:00 with value 76.31
# Imputed missing data at 2011-03-13 02:30:00 with value 75.80
# Imputed missing data at 2012-03-11 02:00:00 with value 76.09
# Imputed missing data at 2012-03-11 02:30:00 with value 76.24
# Imputed missing data at 2012-10-17 09:30:00 with value 76.30
# Imputed missing data at 2012-10-17 10:00:00 with value 76.33
# Imputed missing data at 2012-10-17 10:30:00 with value 76.34
# Imputed missing data at 2012-10-17 11:00:00 with value 76.35
# Imputed missing data at 2012-10-17 11:30:00 with value 76.36
# Imputed missing data at 2013-03-10 02:00:00 with value 76.37
# Imputed missing data at 2013-03-10 02:30:00 with value 76.38
# Imputed missing data at 2013-06-05 14:00:00 with value 77.29
# Imputed missing data at 2013-06-14 10:30:00 with value 77.48
# Imputed missing data at 2013-09-19 08:00:00 with value 76.58
# Imputed missing data at 2013-09-19 08:30:00 with value 76.13
# Imputed missing data at 2013-09-19 09:00:00 with value 75.91
# Imputed missing data at 2013-09-19 09:30:00 with value 75.79
# Imputed missing data at 2013-09-19 10:00:00 with value 75.74
# Imputed missing data at 2013-09-19 10:30:00 with value 75.71
# Imputed missing data at 2013-11-26 18:00:00 with value 75.70
# Imputed missing data at 2014-03-09 02:00:00 with value 76.87
# Imputed missing data at 2014-03-09 02:30:00 with value 77.46
# Imputed missing data at 2014-05-13 16:00:00 with value 78.13
# Imputed missing data at 2014-05-13 16:30:00 with value 78.47
# Imputed missing data at 2014-06-09 12:30:00 with value 78.87
# Imputed missing data at 2014-06-09 13:00:00 with value 79.06
# Imputed missing data at 2014-06-09 13:30:00 with value 79.16
# Imputed missing data at 2014-06-09 14:00:00 with value 79.21
# Imputed missing data at 2014-06-09 14:30:00 with value 79.24
# Imputed missing data at 2014-06-09 15:00:00 with value 79.25
# Imputed missing data at 2014-06-09 15:30:00 with value 79.25
# Imputed missing data at 2014-06-09 16:00:00 with value 79.26
# Imputed missing data at 2014-06-09 16:30:00 with value 79.26
# Imputed missing data at 2014-06-09 17:00:00 with value 79.26
# Imputed missing data at 2014-06-09 17:30:00 with value 79.26
# Imputed missing data at 2014-06-09 18:00:00 with value 79.26
# Imputed missing data at 2014-06-09 18:30:00 with value 79.26
# Imputed missing data at 2014-06-09 19:00:00 with value 79.26
# Imputed missing data at 2014-06-09 19:30:00 with value 79.26
# Imputed missing data at 2014-06-09 20:00:00 with value 79.26
# Imputed missing data at 2014-06-09 20:30:00 with value 79.26
# Imputed missing data at 2014-06-09 21:00:00 with value 79.26
# Imputed missing data at 2014-06-09 21:30:00 with value 79.26
# Imputed missing data at 2014-06-09 22:00:00 with value 79.26
# Imputed missing data at 2014-06-09 22:30:00 with value 79.26
# Imputed missing data at 2014-06-09 23:00:00 with value 79.26
# Imputed missing data at 2014-06-09 23:30:00 with value 79.26
# Imputed missing data at 2014-06-10 00:30:00 with value 79.29
# Imputed missing data at 2014-06-10 01:00:00 with value 79.31
# Imputed missing data at 2014-06-10 01:30:00 with value 79.32
# Imputed missing data at 2014-06-10 02:00:00 with value 79.33
# Imputed missing data at 2014-06-10 02:30:00 with value 79.33
# Imputed missing data at 2014-06-10 03:00:00 with value 79.33
# Imputed missing data at 2014-06-10 03:30:00 with value 79.33
# Imputed missing data at 2014-06-10 04:00:00 with value 79.33
# Imputed missing data at 2014-06-10 04:30:00 with value 79.33
# Imputed missing data at 2014-06-10 05:00:00 with value 79.33
# Imputed missing data at 2014-06-10 05:30:00 with value 79.33
# Imputed missing data at 2014-06-10 06:00:00 with value 79.33
# Imputed missing data at 2014-06-10 06:30:00 with value 79.33
# Imputed missing data at 2014-06-10 07:00:00 with value 79.33
# Imputed missing data at 2014-06-10 07:30:00 with value 79.33
# Imputed missing data at 2014-06-10 08:00:00 with value 79.33
# Imputed missing data at 2014-06-10 08:30:00 with value 79.33
# Imputed missing data at 2014-06-10 09:00:00 with value 79.33
# Imputed missing data at 2014-06-10 09:30:00 with value 79.33
# Imputed missing data at 2014-06-10 10:00:00 with value 79.33
# Imputed missing data at 2014-06-10 10:30:00 with value 79.33
# Imputed missing data at 2014-06-10 11:00:00 with value 79.33
# Imputed missing data at 2014-06-10 11:30:00 with value 79.33
# Imputed missing data at 2014-06-10 12:00:00 with value 79.33
# Imputed missing data at 2014-06-10 12:30:00 with value 79.33
# Imputed missing data at 2014-06-10 13:00:00 with value 79.33
# Imputed missing data at 2014-06-10 13:30:00 with value 79.33
# Imputed missing data at 2014-06-10 14:00:00 with value 79.33
# Imputed missing data at 2014-06-10 14:30:00 with value 79.33
# Imputed missing data at 2014-06-10 15:00:00 with value 79.33
# Imputed missing data at 2014-06-10 15:30:00 with value 79.33
# Imputed missing data at 2014-06-10 16:00:00 with value 79.33
# Imputed missing data at 2014-06-10 16:30:00 with value 79.33
# Imputed missing data at 2014-06-10 17:00:00 with value 79.33
# Imputed missing data at 2014-06-10 17:30:00 with value 79.33
# Imputed missing data at 2014-06-10 18:00:00 with value 79.33
# Imputed missing data at 2014-06-10 18:30:00 with value 79.33
# Imputed missing data at 2014-06-10 19:00:00 with value 79.33
# Imputed missing data at 2014-06-10 19:30:00 with value 79.33
# Imputed missing data at 2014-06-10 20:00:00 with value 79.33
# Imputed missing data at 2014-06-10 20:30:00 with value 79.33
# Imputed missing data at 2014-06-10 21:00:00 with value 79.33
# Imputed missing data at 2014-06-10 21:30:00 with value 79.33
# Imputed missing data at 2014-06-10 22:00:00 with value 79.33
# Imputed missing data at 2014-06-10 22:30:00 with value 79.33
# Imputed missing data at 2014-06-10 23:00:00 with value 79.33
# Imputed missing data at 2014-06-10 23:30:00 with value 79.33
# Imputed missing data at 2014-06-11 00:30:00 with value 78.81
# Imputed missing data at 2014-06-11 01:00:00 with value 78.56
# Imputed missing data at 2014-06-11 01:30:00 with value 78.43
# Imputed missing data at 2014-06-11 02:00:00 with value 78.36
# Imputed missing data at 2014-06-11 02:30:00 with value 78.33
# Imputed missing data at 2014-06-11 03:00:00 with value 78.32
# Imputed missing data at 2014-06-11 03:30:00 with value 78.31
# Imputed missing data at 2014-06-11 04:00:00 with value 78.30
# Imputed missing data at 2014-06-11 04:30:00 with value 78.30
# Imputed missing data at 2014-06-11 05:00:00 with value 78.30
# Imputed missing data at 2014-06-11 05:30:00 with value 78.30
# Imputed missing data at 2014-06-11 06:00:00 with value 78.30
# Imputed missing data at 2014-06-11 06:30:00 with value 78.30
# Imputed missing data at 2014-06-11 07:00:00 with value 78.30
# Imputed missing data at 2014-06-11 07:30:00 with value 78.30
# Imputed missing data at 2014-06-11 08:00:00 with value 78.30
# Imputed missing data at 2014-06-11 08:30:00 with value 78.30
# Imputed missing data at 2014-06-11 09:00:00 with value 78.30
# Imputed missing data at 2014-06-11 09:30:00 with value 78.30
# Imputed missing data at 2014-07-24 15:00:00 with value 77.89
# Imputed missing data at 2014-07-24 15:30:00 with value 77.68
# Imputed missing data at 2014-07-24 16:00:00 with value 77.57
# Imputed missing data at 2014-10-16 05:00:00 with value 76.78
# Imputed missing data at 2014-10-16 05:30:00 with value 76.38
# Imputed missing data at 2014-10-16 06:00:00 with value 76.18
# Imputed missing data at 2014-10-16 06:30:00 with value 76.08
# Imputed missing data at 2014-10-16 07:00:00 with value 76.03
# Imputed missing data at 2014-10-16 07:30:00 with value 76.00
# Imputed missing data at 2014-10-16 08:00:00 with value 75.99
# Imputed missing data at 2014-10-16 08:30:00 with value 75.99
# Imputed missing data at 2014-10-16 09:00:00 with value 75.98
# Imputed missing data at 2014-10-16 09:30:00 with value 75.98
# Imputed missing data at 2014-10-16 10:00:00 with value 75.98
# Imputed missing data at 2014-10-16 10:30:00 with value 75.98
# Imputed missing data at 2014-10-16 11:00:00 with value 75.98
# Imputed missing data at 2014-10-16 11:30:00 with value 75.98
# Imputed missing data at 2014-10-16 12:00:00 with value 75.98
# Imputed missing data at 2014-10-16 12:30:00 with value 75.98
# Imputed missing data at 2014-10-16 13:00:00 with value 75.98
# Imputed missing data at 2014-10-16 13:30:00 with value 75.98
# Imputed missing data at 2014-10-16 14:00:00 with value 75.98
# Imputed missing data at 2014-10-16 14:30:00 with value 75.98
# Imputed missing data at 2014-10-16 15:00:00 with value 75.98
# Imputed missing data at 2014-10-16 15:30:00 with value 75.98
# Imputed missing data at 2014-10-16 16:00:00 with value 75.98
# Imputed missing data at 2014-10-16 16:30:00 with value 75.98
# Imputed missing data at 2014-10-16 17:00:00 with value 75.98
# Imputed missing data at 2014-10-16 17:30:00 with value 75.98
# Imputed missing data at 2014-10-16 18:00:00 with value 75.98
# Imputed missing data at 2014-10-16 18:30:00 with value 75.98
# Imputed missing data at 2014-10-16 19:00:00 with value 75.98
# Imputed missing data at 2014-10-16 19:30:00 with value 75.98
# Imputed missing data at 2014-10-16 20:00:00 with value 75.98
# Imputed missing data at 2014-10-16 20:30:00 with value 75.98
# Imputed missing data at 2014-10-16 21:00:00 with value 75.98
# Imputed missing data at 2014-10-16 21:30:00 with value 75.98
# Imputed missing data at 2014-10-16 22:00:00 with value 75.98
# Imputed missing data at 2014-10-16 22:30:00 with value 75.98
# Imputed missing data at 2014-10-16 23:00:00 with value 75.98
# Imputed missing data at 2014-10-16 23:30:00 with value 75.98
# Imputed missing data at 2014-10-17 00:00:00 with value 75.98
# Imputed missing data at 2014-10-17 00:30:00 with value 75.98
# Imputed missing data at 2014-10-17 01:00:00 with value 75.98
# Imputed missing data at 2014-10-17 01:30:00 with value 75.98
# Imputed missing data at 2014-10-17 02:00:00 with value 75.98
# Imputed missing data at 2014-10-17 02:30:00 with value 75.98
# Imputed missing data at 2014-10-17 03:00:00 with value 75.98
# Imputed missing data at 2014-10-17 03:30:00 with value 75.98
# Imputed missing data at 2014-10-17 04:00:00 with value 75.98
# Imputed missing data at 2014-10-17 04:30:00 with value 75.98
# Imputed missing data at 2014-10-17 05:00:00 with value 75.98
# Imputed missing data at 2014-10-17 05:30:00 with value 75.98
# Imputed missing data at 2014-10-17 06:00:00 with value 75.98
# Imputed missing data at 2014-10-17 06:30:00 with value 75.98
# Imputed missing data at 2014-10-17 07:00:00 with value 75.98
# Imputed missing data at 2014-10-17 07:30:00 with value 75.98
# Imputed missing data at 2014-10-17 08:00:00 with value 75.98
# Imputed missing data at 2014-10-17 08:30:00 with value 75.98
# Imputed missing data at 2014-10-17 09:00:00 with value 75.98
# Imputed missing data at 2014-10-17 09:30:00 with value 75.98
# Imputed missing data at 2014-10-17 10:00:00 with value 75.98
# Imputed missing data at 2015-03-08 02:00:00 with value 76.08
# Imputed missing data at 2015-03-08 02:30:00 with value 76.13
# Imputed missing data at 2015-03-26 12:00:00 with value 77.30
# Imputed missing data at 2016-03-13 02:00:00 with value 76.97
# Imputed missing data at 2016-03-13 02:30:00 with value 76.81
# Imputed missing data at 2016-10-01 18:30:00 with value 75.94
# Imputed missing data at 2016-10-01 19:00:00 with value 75.50
# Imputed missing data at 2016-10-01 19:30:00 with value 75.29
# Imputed missing data at 2016-10-01 20:00:00 with value 75.18
# Imputed missing data at 2016-10-01 20:30:00 with value 75.12
# Imputed missing data at 2016-10-01 21:00:00 with value 75.10
# Imputed missing data at 2016-10-01 21:30:00 with value 75.08
# Imputed missing data at 2016-10-01 22:00:00 with value 75.08
# Imputed missing data at 2016-10-01 22:30:00 with value 75.07
# Imputed missing data at 2016-10-01 23:00:00 with value 75.07
# Imputed missing data at 2016-10-01 23:30:00 with value 75.07
# Imputed missing data at 2016-10-02 00:00:00 with value 75.07
# Imputed missing data at 2016-10-02 00:30:00 with value 75.07
# Imputed missing data at 2016-10-02 01:00:00 with value 75.07
# Imputed missing data at 2016-10-02 01:30:00 with value 75.07
# Imputed missing data at 2016-10-02 02:00:00 with value 75.07
# Imputed missing data at 2016-10-02 02:30:00 with value 75.07
# Imputed missing data at 2016-10-02 03:00:00 with value 75.07
# Imputed missing data at 2016-10-02 03:30:00 with value 75.07
# Imputed missing data at 2016-10-02 04:00:00 with value 75.07
# Imputed missing data at 2016-10-02 04:30:00 with value 75.07
# Imputed missing data at 2016-10-02 05:00:00 with value 75.07
# Imputed missing data at 2016-10-02 05:30:00 with value 75.07
# Imputed missing data at 2016-10-02 06:00:00 with value 75.07
# Imputed missing data at 2016-10-02 06:30:00 with value 75.07
# Imputed missing data at 2016-10-02 07:00:00 with value 75.07
# Imputed missing data at 2016-10-02 07:30:00 with value 75.07
# Imputed missing data at 2016-10-02 08:00:00 with value 75.07
# Imputed missing data at 2016-10-02 08:30:00 with value 75.07
# Imputed missing data at 2016-10-02 09:00:00 with value 75.07
# Imputed missing data at 2016-10-02 09:30:00 with value 75.07
# Imputed missing data at 2016-10-02 10:00:00 with value 75.07
# Imputed missing data at 2016-10-02 10:30:00 with value 75.07
# Imputed missing data at 2016-10-02 11:00:00 with value 75.07
# Imputed missing data at 2016-10-02 12:00:00 with value 75.07
# Imputed missing data at 2016-10-02 16:30:00 with value 75.06
# Imputed missing data at 2016-10-02 17:00:00 with value 75.05
# Imputed missing data at 2016-10-02 17:30:00 with value 75.05
# Imputed missing data at 2016-10-02 18:00:00 with value 75.05
# Imputed missing data at 2016-10-02 18:30:00 with value 75.05
# Imputed missing data at 2016-10-02 19:00:00 with value 75.05
# Imputed missing data at 2016-10-02 19:30:00 with value 75.05
# Imputed missing data at 2016-10-02 20:00:00 with value 75.05
# Imputed missing data at 2016-10-02 20:30:00 with value 75.05
# Imputed missing data at 2016-10-02 21:00:00 with value 75.05
# Imputed missing data at 2016-10-02 21:30:00 with value 75.05
# Imputed missing data at 2016-10-02 22:00:00 with value 75.05
# Imputed missing data at 2016-10-02 22:30:00 with value 75.05
# Imputed missing data at 2016-10-02 23:00:00 with value 75.05
# Imputed missing data at 2016-10-02 23:30:00 with value 75.05
# Imputed missing data at 2016-10-03 00:00:00 with value 75.05
# Imputed missing data at 2016-10-03 00:30:00 with value 75.05
# Imputed missing data at 2016-10-03 01:00:00 with value 75.05
# Imputed missing data at 2016-10-03 01:30:00 with value 75.05
# Imputed missing data at 2016-10-03 02:00:00 with value 75.05
# Imputed missing data at 2016-10-03 02:30:00 with value 75.05
# Imputed missing data at 2016-10-03 03:00:00 with value 75.05
# Imputed missing data at 2016-10-03 03:30:00 with value 75.05
# Imputed missing data at 2016-10-03 04:00:00 with value 75.05
# Imputed missing data at 2016-10-03 04:30:00 with value 75.05
# Imputed missing data at 2016-10-03 05:00:00 with value 75.05
# Imputed missing data at 2016-10-03 05:30:00 with value 75.05
# Imputed missing data at 2016-10-03 06:00:00 with value 75.05
# Imputed missing data at 2016-10-03 06:30:00 with value 75.05
# Imputed missing data at 2016-10-03 07:00:00 with value 75.05
# Imputed missing data at 2016-10-03 07:30:00 with value 75.05
# Imputed missing data at 2016-10-03 08:00:00 with value 75.05
# Imputed missing data at 2016-10-03 08:30:00 with value 75.05
# Imputed missing data at 2016-10-03 09:00:00 with value 75.05
# Imputed missing data at 2016-10-03 09:30:00 with value 75.05
# Imputed missing data at 2016-10-03 10:00:00 with value 75.05
# Imputed missing data at 2016-10-03 10:30:00 with value 75.05
# Imputed missing data at 2016-10-03 11:00:00 with value 75.05
# Imputed missing data at 2016-10-03 11:30:00 with value 75.05
# Imputed missing data at 2016-10-03 12:00:00 with value 75.05
# Imputed missing data at 2016-10-03 12:30:00 with value 75.05
# Imputed missing data at 2016-10-03 13:00:00 with value 75.05
# Imputed missing data at 2016-10-03 13:30:00 with value 75.05
# Imputed missing data at 2016-10-03 14:00:00 with value 75.05
# Imputed missing data at 2016-10-03 14:30:00 with value 75.05
# Imputed missing data at 2016-10-03 15:00:00 with value 75.05
# Imputed missing data at 2016-10-03 15:30:00 with value 75.05
# Imputed missing data at 2016-10-03 16:00:00 with value 75.05
# Imputed missing data at 2016-10-03 16:30:00 with value 75.05
# Imputed missing data at 2016-10-03 17:00:00 with value 75.05
# Imputed missing data at 2016-10-03 17:30:00 with value 75.05
# Imputed missing data at 2016-10-03 18:00:00 with value 75.05
# Imputed missing data at 2016-10-03 18:30:00 with value 75.05
# Imputed missing data at 2016-10-03 19:00:00 with value 75.05
# Imputed missing data at 2016-10-03 19:30:00 with value 75.05
# Imputed missing data at 2016-10-03 20:00:00 with value 75.05
# Imputed missing data at 2016-10-03 20:30:00 with value 75.05
# Imputed missing data at 2016-10-03 21:00:00 with value 75.05
# Imputed missing data at 2016-10-03 21:30:00 with value 75.05
# Imputed missing data at 2016-10-03 22:00:00 with value 75.05
# Imputed missing data at 2016-10-03 22:30:00 with value 75.05
# Imputed missing data at 2016-10-03 23:00:00 with value 75.05
# Imputed missing data at 2016-10-03 23:30:00 with value 75.05
# Imputed missing data at 2016-10-04 00:00:00 with value 75.05
# Imputed missing data at 2016-10-04 00:30:00 with value 75.05
# Imputed missing data at 2016-10-04 01:00:00 with value 75.05
# Imputed missing data at 2016-10-04 01:30:00 with value 75.05
# Imputed missing data at 2016-10-04 02:00:00 with value 75.05
# Imputed missing data at 2016-10-04 02:30:00 with value 75.05
# Imputed missing data at 2016-10-04 03:00:00 with value 75.05
# Imputed missing data at 2016-10-04 03:30:00 with value 75.05
# Imputed missing data at 2016-10-04 04:00:00 with value 75.05
# Imputed missing data at 2016-10-04 04:30:00 with value 75.05
# Imputed missing data at 2016-10-04 05:00:00 with value 75.05
# Imputed missing data at 2016-10-04 05:30:00 with value 75.05
# Imputed missing data at 2016-10-04 06:00:00 with value 75.05
# Imputed missing data at 2016-10-04 06:30:00 with value 75.05
# Imputed missing data at 2016-10-04 07:00:00 with value 75.05
# Imputed missing data at 2016-10-04 07:30:00 with value 75.05
# Imputed missing data at 2016-10-04 08:00:00 with value 75.05
# Imputed missing data at 2016-10-04 08:30:00 with value 75.05
# Imputed missing data at 2016-10-04 09:00:00 with value 75.05
# Imputed missing data at 2016-10-04 09:30:00 with value 75.05
# Imputed missing data at 2016-10-04 10:00:00 with value 75.05
# Imputed missing data at 2016-10-04 10:30:00 with value 75.05
# Imputed missing data at 2017-03-12 02:00:00 with value 77.64
# Imputed missing data at 2017-03-12 02:30:00 with value 78.93
# Imputed missing data at 2017-06-15 03:30:00 with value 80.12
# Imputed missing data at 2018-03-11 02:00:00 with value 77.80
# Imputed missing data at 2018-03-11 02:30:00 with value 76.64
# Imputed missing data at 2018-03-15 11:30:00 with value 76.42
# Imputed missing data at 2018-03-15 12:00:00 with value 76.30
# Imputed missing data at 2019-03-10 02:00:00 with value 75.16
# Imputed missing data at 2019-03-10 02:30:00 with value 74.59
# Imputed missing data at 2019-10-09 11:30:00 with value 75.57
# Imputed missing data at 2019-10-09 12:30:00 with value 76.01
# Imputed missing data at 2019-10-09 13:00:00 with value 76.24
# Imputed missing data at 2020-03-08 02:00:00 with value 76.10
# Imputed missing data at 2020-03-08 02:30:00 with value 76.03
# Imputed missing data at 2021-03-14 02:00:00 with value 75.60
# Imputed missing data at 2021-03-14 02:30:00 with value 75.38
# Imputed missing data at 2022-03-13 02:00:00 with value 75.62
# Imputed missing data at 2022-03-13 02:30:00 with value 75.74
# Imputed missing data at 2023-03-12 02:00:00 with value 75.81
# Imputed missing data at 2023-03-12 02:30:00 with value 75.85
# Imputed missing data at 2023-05-03 12:30:00 with value 77.40
# Imputed missing data at 2023-10-25 14:00:00 with value 76.60
# Imputed missing data at 2024-03-10 02:00:00 with value 75.80
# Imputed missing data at 2024-03-10 02:30:00 with value 75.39
# Imputed missing data at 2024-03-18 13:30:00 with value 74.65
# Imputed missing data at 2024-03-18 14:00:00 with value 74.28
# Imputed missing data at 2024-03-18 14:30:00 with value 74.10
# Imputed missing data at 2024-03-29 01:30:00 with value 75.26
# Imputed missing data at 2024-04-02 14:30:00 with value 75.35
# Imputed missing data at 2024-04-02 15:00:00 with value 75.40
# Imputed missing data at 2024-05-09 10:30:00 with value 74.89
# Imputed missing data at 2024-09-09 10:00:00 with value 75.50
# Imputed missing data at 2024-09-19 12:30:00 with value 75.87
# Imputed missing data at 2024-10-29 15:30:00 with value 75.54
# Imputed missing data at 2024-10-30 15:30:00 with value 75.40
# Imputed missing data at 2024-10-31 09:00:00 with value 75.82
# Imputed missing data at 2024-10-31 23:30:00 with value 75.90
# Imputed missing data at 2024-11-01 01:30:00 with value 75.97
# Imputed missing data at 2024-11-01 06:30:00 with value 75.87
# Imputed missing data at 2024-11-01 08:00:00 with value 75.94
# Imputed missing data at 2024-11-01 09:00:00 with value 76.04
# Imputed missing data at 2024-11-01 10:00:00 with value 76.11
# Imputed missing data at 2024-11-01 10:30:00 with value 76.15
# Imputed missing data at 2024-11-01 16:00:00 with value 76.18
# Imputed missing data at 2024-11-01 17:00:00 with value 76.38
# Imputed missing data at 2024-11-01 18:00:00 with value 76.46
# Imputed missing data at 2024-11-01 20:00:00 with value 76.56
# Imputed missing data at 2024-11-02 02:00:00 with value 76.69
# Imputed missing data at 2024-11-02 02:30:00 with value 76.76
# Imputed missing data at 2024-11-02 06:00:00 with value 76.71
# Imputed missing data at 2024-11-02 07:00:00 with value 76.80
# Imputed missing data at 2024-11-02 08:00:00 with value 76.85
# Imputed missing data at 2024-11-02 08:30:00 with value 76.87
# Imputed missing data at 2024-11-02 15:00:00 with value 76.74
# Imputed missing data at 2024-11-02 18:30:00 with value 76.62
# Imputed missing data at 2024-11-02 20:00:00 with value 76.57
# Imputed missing data at 2024-11-02 22:30:00 with value 76.52
# Imputed missing data at 2024-11-02 23:30:00 with value 76.51
# Imputed missing data at 2024-11-03 08:30:00 with value 76.33
# Imputed missing data at 2024-11-03 09:30:00 with value 76.32
# Imputed missing data at 2024-11-03 11:30:00 with value 76.26
# Imputed missing data at 2024-11-03 14:00:00 with value 76.23
# Imputed missing data at 2024-11-03 15:00:00 with value 76.21
# Imputed missing data at 2024-11-03 17:30:00 with value 76.16
# Imputed missing data at 2024-11-03 18:00:00 with value 76.13
# Imputed missing data at 2024-11-03 20:00:00 with value 76.14
# Imputed missing data at 2024-11-03 21:00:00 with value 76.16
# Imputed missing data at 2024-11-04 00:00:00 with value 76.14
# Imputed missing data at 2024-11-04 01:30:00 with value 76.09
# Imputed missing data at 2024-11-04 02:00:00 with value 76.06
# Imputed missing data at 2024-11-04 02:30:00 with value 76.04
# Imputed missing data at 2024-11-04 04:00:00 with value 75.99
# Imputed missing data at 2024-11-04 04:30:00 with value 75.97
# Imputed missing data at 2024-11-04 08:30:00 with value 75.94
# Imputed missing data at 2024-11-04 12:00:00 with value 75.95
# Imputed missing data at 2024-11-04 14:30:00 with value 75.95
# Imputed missing data at 2024-11-04 18:30:00 with value 76.06
# Imputed missing data at 2024-11-04 20:30:00 with value 76.25
# Imputed missing data at 2024-11-04 21:00:00 with value 76.34
# Imputed missing data at 2024-11-04 21:30:00 with value 76.39
# Imputed missing data at 2024-11-04 23:00:00 with value 76.26
# Imputed missing data at 2024-11-05 04:30:00 with value 76.01
# Imputed missing data at 2024-11-05 05:30:00 with value 75.87
# Imputed missing data at 2024-11-05 08:00:00 with value 75.77
# Imputed missing data at 2024-11-05 10:00:00 with value 75.72
# Imputed missing data at 2024-11-05 14:30:00 with value 75.73
# Imputed missing data at 2024-11-05 15:00:00 with value 75.74
# Imputed missing data at 2024-11-05 16:00:00 with value 75.73
# Imputed missing data at 2024-11-05 17:00:00 with value 75.73
# Imputed missing data at 2024-11-05 20:00:00 with value 75.84
# Imputed missing data at 2024-11-06 00:30:00 with value 75.63
# Imputed missing data at 2024-11-06 01:00:00 with value 75.52
# Imputed missing data at 2024-11-06 01:30:00 with value 75.46
# Imputed missing data at 2024-11-06 03:00:00 with value 75.39
# Imputed missing data at 2024-11-06 05:00:00 with value 75.30
# Imputed missing data at 2024-11-06 06:00:00 with value 75.34
# Imputed missing data at 2024-11-06 09:00:00 with value 75.18
# Imputed missing data at 2024-11-06 10:00:00 with value 75.17
# Imputed missing data at 2024-11-06 12:00:00 with value 75.18
# Imputed missing data at 2024-11-06 19:00:00 with value 75.35
# Imputed missing data at 2024-11-06 19:30:00 with value 75.44
# Imputed missing data at 2024-11-07 00:30:00 with value 75.37
# Imputed missing data at 2024-11-07 03:00:00 with value 75.25
# Imputed missing data at 2024-11-07 03:30:00 with value 75.19
# Imputed missing data at 2024-11-07 10:00:00 with value 75.37
# Imputed missing data at 2024-11-07 13:00:00 with value 75.40
# Imputed missing data at 2024-11-07 14:00:00 with value 75.43
# Imputed missing data at 2024-11-07 14:30:00 with value 75.44
# Imputed missing data at 2024-11-07 15:00:00 with value 75.45
# Imputed missing data at 2024-11-07 15:30:00 with value 75.46
# Imputed missing data at 2024-11-08 00:30:00 with value 75.37
# Imputed missing data at 2024-11-08 01:00:00 with value 75.33
# Imputed missing data at 2024-11-08 01:30:00 with value 75.31
# Imputed missing data at 2024-11-08 02:00:00 with value 75.30
# Imputed missing data at 2024-11-08 02:30:00 with value 75.30
# Imputed missing data at 2024-11-08 04:30:00 with value 75.29
# Imputed missing data at 2024-11-08 09:30:00 with value 75.45
# Imputed missing data at 2024-11-08 10:00:00 with value 75.53
# Imputed missing data at 2024-11-08 10:30:00 with value 75.57
# Imputed missing data at 2024-11-08 11:00:00 with value 75.59
# Imputed missing data at 2024-11-08 11:30:00 with value 75.60
# Imputed missing data at 2024-11-08 14:00:00 with value 75.51
# Imputed missing data at 2024-11-08 14:30:00 with value 75.47
# Imputed missing data at 2024-11-09 00:30:00 with value 75.37
# Imputed missing data at 2024-11-09 01:00:00 with value 75.32
# Imputed missing data at 2024-11-09 01:30:00 with value 75.30
# Imputed missing data at 2024-11-09 02:00:00 with value 75.28
# Imputed missing data at 2024-11-09 02:30:00 with value 75.28
# Imputed missing data at 2024-11-09 03:00:00 with value 75.27
# Imputed missing data at 2024-11-09 03:30:00 with value 75.27
# Imputed missing data at 2024-11-09 04:00:00 with value 75.27
# Imputed missing data at 2024-11-09 04:30:00 with value 75.27
# Imputed missing data at 2024-11-09 05:00:00 with value 75.27
# Imputed missing data at 2024-11-09 05:30:00 with value 75.27
# Imputed missing data at 2024-11-09 06:00:00 with value 75.27
# Imputed missing data at 2024-11-09 06:30:00 with value 75.27
# Imputed missing data at 2024-11-09 07:00:00 with value 75.27
# Imputed missing data at 2024-11-09 07:30:00 with value 75.27
# Imputed missing data at 2024-11-09 08:00:00 with value 75.27
# Imputed missing data at 2024-11-09 08:30:00 with value 75.27
# Imputed missing data at 2024-11-09 09:00:00 with value 75.27
# Imputed missing data at 2024-11-09 09:30:00 with value 75.27
# Imputed missing data at 2024-11-09 10:00:00 with value 75.27
# Imputed missing data at 2024-11-09 10:30:00 with value 75.27
# Imputed missing data at 2024-11-09 11:00:00 with value 75.27
# Imputed missing data at 2024-11-09 11:30:00 with value 75.27
# Imputed missing data at 2024-11-09 12:00:00 with value 75.27
# Imputed missing data at 2024-11-09 12:30:00 with value 75.27
# Imputed missing data at 2024-11-09 13:00:00 with value 75.27
# Imputed missing data at 2024-11-09 13:30:00 with value 75.27
# Imputed missing data at 2024-11-10 00:30:00 with value 75.16
# Imputed missing data at 2024-11-10 01:00:00 with value 75.10
# Imputed missing data at 2024-11-10 01:30:00 with value 75.07
# Imputed missing data at 2024-11-10 02:00:00 with value 75.05
# Imputed missing data at 2024-11-10 02:30:00 with value 75.05
# Imputed missing data at 2024-11-10 03:00:00 with value 75.04
# Imputed missing data at 2024-11-10 03:30:00 with value 75.04
# Imputed missing data at 2024-11-10 04:00:00 with value 75.04
# Imputed missing data at 2024-11-10 04:30:00 with value 75.04
# Imputed missing data at 2024-11-10 05:00:00 with value 75.04
# Imputed missing data at 2024-11-11 00:30:00 with value 74.71
# Imputed missing data at 2024-11-11 01:00:00 with value 74.55
# Imputed missing data at 2024-11-11 01:30:00 with value 74.46
# Imputed missing data at 2024-11-11 02:00:00 with value 74.42
# Imputed missing data at 2024-11-11 02:30:00 with value 74.40
# Imputed missing data at 2024-11-11 03:00:00 with value 74.39
# Imputed missing data at 2024-11-11 03:30:00 with value 74.39
# Imputed missing data at 2024-11-11 04:00:00 with value 74.38
# Imputed missing data at 2024-11-11 04:30:00 with value 74.38
# Imputed missing data at 2024-11-11 05:00:00 with value 74.38
# Imputed missing data at 2024-11-11 05:30:00 with value 74.38
# Imputed missing data at 2024-11-11 06:00:00 with value 74.38
# Imputed missing data at 2024-11-11 06:30:00 with value 74.38
# Imputed missing data at 2024-11-11 07:00:00 with value 74.38
# Imputed missing data at 2024-11-11 07:30:00 with value 74.38
# Imputed missing data at 2024-11-11 08:00:00 with value 74.38
# Imputed missing data at 2024-11-11 08:30:00 with value 74.38
# Imputed missing data at 2024-11-11 09:00:00 with value 74.38
# Imputed missing data at 2024-11-11 09:30:00 with value 74.38
# Imputed missing data at 2024-11-11 10:00:00 with value 74.38
# Imputed missing data at 2024-11-11 10:30:00 with value 74.38
# Imputed missing data at 2024-11-11 11:00:00 with value 74.38
# Imputed missing data at 2024-11-11 11:30:00 with value 74.38
# Imputed missing data at 2024-11-11 12:00:00 with value 74.38
# Imputed missing data at 2024-11-11 12:30:00 with value 74.38
# Imputed missing data at 2024-11-12 00:30:00 with value 74.89
# Imputed missing data at 2024-11-12 01:00:00 with value 75.15
# Imputed missing data at 2024-11-12 01:30:00 with value 75.27
# Imputed missing data at 2024-11-12 02:00:00 with value 75.34
# Imputed missing data at 2024-11-12 02:30:00 with value 75.37
# Imputed missing data at 2024-11-12 03:00:00 with value 75.38
# Imputed missing data at 2024-11-12 03:30:00 with value 75.39
# Imputed missing data at 2024-11-12 04:00:00 with value 75.40
# Imputed missing data at 2024-11-12 04:30:00 with value 75.40
# Imputed missing data at 2024-11-12 05:00:00 with value 75.40
# Imputed missing data at 2024-11-12 05:30:00 with value 75.40
# Imputed missing data at 2024-11-12 06:00:00 with value 75.40
# Imputed missing data at 2024-11-12 06:30:00 with value 75.40
# Imputed missing data at 2024-11-12 07:00:00 with value 75.40
# Imputed missing data at 2024-11-12 07:30:00 with value 75.40
# Imputed missing data at 2024-11-12 08:00:00 with value 75.40
# Imputed missing data at 2024-11-12 08:30:00 with value 75.40
# Imputed missing data at 2024-11-12 09:00:00 with value 75.40
# Imputed missing data at 2024-11-12 09:30:00 with value 75.40
# Imputed missing data at 2024-11-12 10:00:00 with value 75.40
# Imputed missing data at 2024-11-12 10:30:00 with value 75.40
# Imputed missing data at 2024-11-12 11:00:00 with value 75.40
# Imputed missing data at 2024-11-12 11:30:00 with value 75.40
# Imputed missing data at 2024-11-12 12:00:00 with value 75.40
# Imputed missing data at 2024-11-12 12:30:00 with value 75.40
# Imputed missing data at 2024-11-12 13:00:00 with value 75.40
# Imputed missing data at 2024-11-12 13:30:00 with value 75.40
# Imputed missing data at 2024-11-12 14:00:00 with value 75.40
# Imputed missing data at 2024-11-12 14:30:00 with value 75.40
# Imputed missing data at 2024-11-12 15:00:00 with value 75.40
# Imputed missing data at 2024-11-12 15:30:00 with value 75.40
# Imputed missing data at 2024-11-12 16:00:00 with value 75.40
# Imputed missing data at 2024-11-12 16:30:00 with value 75.40
# Imputed missing data at 2024-11-12 17:00:00 with value 75.40
# Imputed missing data at 2024-11-12 17:30:00 with value 75.40
# Imputed missing data at 2024-11-12 18:00:00 with value 75.40
# Imputed missing data at 2024-11-12 18:30:00 with value 75.40
# Imputed missing data at 2024-11-12 19:00:00 with value 75.40
# Imputed missing data at 2024-11-12 19:30:00 with value 75.40
# Imputed missing data at 2024-11-12 20:00:00 with value 75.40
# Imputed missing data at 2024-11-12 20:30:00 with value 75.40
# Imputed missing data at 2024-11-12 21:00:00 with value 75.40
# Imputed missing data at 2024-11-12 21:30:00 with value 75.40
# Imputed missing data at 2024-11-12 22:00:00 with value 75.40
# Imputed missing data at 2024-11-12 22:30:00 with value 75.40
# Imputed missing data at 2024-11-12 23:00:00 with value 75.40
# Imputed missing data at 2024-11-12 23:30:00 with value 75.40
# Imputed missing data at 2024-11-13 00:00:00 with value 75.40
# Imputed missing data at 2024-11-13 00:30:00 with value 75.40
# Imputed missing data at 2024-11-13 01:00:00 with value 75.40
# Imputed missing data at 2024-11-13 01:30:00 with value 75.40
# Imputed missing data at 2024-11-13 02:00:00 with value 75.40
# Imputed missing data at 2024-11-13 02:30:00 with value 75.40
# Imputed missing data at 2024-11-13 03:00:00 with value 75.40
# Imputed missing data at 2024-11-13 03:30:00 with value 75.40
# Imputed missing data at 2024-11-13 04:00:00 with value 75.40
# Imputed missing data at 2024-11-13 04:30:00 with value 75.40
# Imputed missing data at 2024-11-13 05:00:00 with value 75.40
# Imputed missing data at 2024-11-13 05:30:00 with value 75.40
# Imputed missing data at 2024-11-13 06:00:00 with value 75.40
# Imputed missing data at 2024-11-13 06:30:00 with value 75.40
# Imputed missing data at 2024-11-13 07:00:00 with value 75.40
# Imputed missing data at 2024-11-13 07:30:00 with value 75.40
# Imputed missing data at 2024-11-13 08:00:00 with value 75.40
# Imputed missing data at 2024-11-13 08:30:00 with value 75.40
# Imputed missing data at 2024-11-13 09:00:00 with value 75.40
#
# Imputed 887 rows

# %% [markdown]
# ## Data Visualization: Preprocessing

# %%
## Isolate streamflow gauage series

# df: Stevenson, downstream, inflow
# df2: Dallas Dam, upstream, outflow

x = df2['00065'].to_numpy() ## OUTFLOW
y = df['00065'].to_numpy() ## INFLOW
dates = df.index

# Check if same length
print(len(x), len(y))
# Out:
# 280512 280512

# %% [markdown]
# ### Plot #1: Streamflow

# %%
plt.plot(dates, x, label = 'Upstream')
plt.plot(dates, y, label = 'Downstream')

plt.title('Streamflow ' + date_range)
plt.xlabel("Time Interval [" + str(int_freq) + " min]")
plt.ylabel("Gage Height [ft]")
plt.legend()

# Set how many x-axis labels you want
num_labels_to_show = 8
# Calculate evenly spaced indices
indices = np.linspace(0, len(dates) - 1, num_labels_to_show, dtype=int)
selected_dates = dates[indices]

# Apply sampled ticks and rotated labels
ax = plt.gca()
ax.set_xticks(selected_dates)
ax.set_xticklabels(selected_dates.strftime('%Y-%m-%d'), rotation=-45)


plt.show()

# %% [markdown]
# ### Plot #2: Detrended Streamflow

# %%
x_bar = x - np.mean(x)
y_bar = y - np.mean(y)

# %%
plt.plot(dates, x_bar, label = 'Upstream')
plt.plot(dates, y_bar, label = 'Downstream')

plt.title('Detrended Streamflow ' + date_range)
plt.legend()
plt.xlabel("Time Interval [" + str(int_freq) + " min]")
plt.ylabel("Gage Height [ft]")

# Apply sampled ticks and rotated labels
ax = plt.gca()
ax.set_xticks(selected_dates)
ax.set_xticklabels(selected_dates.strftime('%Y-%m-%d'), rotation=-45)

plt.show()

# %% [markdown]
# ## Daily Cross-Correlation Analysis

# %%
max_lag = 72 # one day
correlations = [np.corrcoef(x[:-lag], y[lag:])[0,1] for lag in range(1, max_lag+1)]

best_lag = np.argmax(correlations) + 1  
print(f"Optimal delay: {best_lag*(int_freq/60)} hours") # convert min invervals to hours
# Out:
# Optimal delay: 2.0 hours

# %% [markdown]
# ## Data Visualization: Postprocessing

# %% [markdown]
# ### Plot #3: Detrended & Delagged Streamflow

# %%
plt.plot(dates[:-best_lag], x_bar[:-best_lag], label = 'Upstream')
plt.plot(dates[best_lag:], y_bar[best_lag:], label = 'Downstream')
plt.title('Detrended & Delagged Streamflow ' + date_range)
plt.legend()
plt.xlabel("Time Interval [" + str(int_freq) + " min]")
plt.ylabel("Gage Height [ft]")

# Apply sampled ticks and rotated labels
ax = plt.gca()
ax.set_xticks(selected_dates)
ax.set_xticklabels(selected_dates.strftime('%Y-%m-%d'), rotation=-45)

plt.show()

# %% [markdown]
# ### Plot #4a: Error

# %%
# loss from upstream to downstream 
loss = x_bar[:-best_lag]-y_bar[best_lag:]
plt.plot(dates[best_lag:], loss, label = 'Loss')
plt.title('Delagged & Detrended Streamflow Difference')
plt.legend()
plt.xlabel("Time Interval [" + str(int_freq) + " min]")
plt.ylabel("Difference [ft]")

# Apply sampled ticks and rotated labels
ax = plt.gca()
ax.set_xticks(selected_dates)
ax.set_xticklabels(selected_dates.strftime('%Y-%m-%d'), rotation=-45)

plt.show()

# %% [markdown]
# ### Plot #4: Error Histogram

# %%
plt.hist(loss) # scatter
plt.title("Histogram of Streamflow Difference")
plt.show()

# %% [markdown]
# ### Plot #5: Correlations

# %%
plt.plot(correlations)
plt.show()

# %% [markdown]
# ## Cross-Correlation Distribution

# %%
# Parameters
intervals_per_day = int((60/int_freq)*24)  # 30-min data → 48 points/day
max_lag = int(intervals_per_day/4)  # Limit lag search to 12 hours
num_days = len(x) // intervals_per_day

# Store optimal lag per day
optimal_lags = []

for day in range(num_days-1):
    
    start = day * intervals_per_day 
    end = start + intervals_per_day + max_lag  # Extra for lagging

    # Skip if not enough data left for full lag window
    if end > len(x):
        break

    x_day = x[start:end]
    y_day = y[start:end]
    
    correlations = [np.corrcoef(x_day[:-lag], y_day[lag:])[0,1] for lag in range(1, max_lag+1)]
    best_lag = np.argmax(correlations) + 1
    optimal_lags.append(best_lag)

# Convert to numpy array and optionally to hours
optimal_lags = np.array(optimal_lags)
optimal_lags_hours = optimal_lags * (int_freq/60)  # convert min invervals to hours
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
plt.hist(optimal_lags_hours, bins=10)
plt.title('Distribution of Lag Times, Max Lag = ' + str(max_lag/2) + ' hrs')
plt.ylabel('Frequency')
plt.xlabel('Lag Time [hrs]')
plt.show()

# %% [markdown]
# # Regression Visualization

# %%
month_start = '04-01'
month_end = '08-31'

train_start_date = '2008-' + month_start
train_end_date = '2023-' + month_end

test_start_date = '2024-' + month_start
test_end_date = '2024-' + month_end

# %%
# Isolate train and testing data
df_range = df[(df.index >= train_start_date)]

mask = (
    (df_range.index.strftime('%m-%d') >= month_start) &
    (df_range.index.strftime('%m-%d') <= month_end)
)

df_range = df_range[mask]
df_range = df_range.rename(columns={'00065': 'y'}) ## df: inflow downstream

# Merge in upstream data
df_range = df_range.merge(df2, left_index=True, right_index=True, how='inner')
df_range = df_range.rename(columns={'00065': 'x'})
df_range = df_range[['y', 'x']]

# Calculate day of year as feature
df_range['DoY'] = pd.to_datetime(df_range.index).strftime('%j').astype(int)

# %%
# Normalize features
scaler = StandardScaler()
df_range_norm = scaler.fit_transform(df_range)

# col 1: y
df_range['y_norm'] = df_range_norm[:,0]
# col 2: x
df_range['x_norm'] = df_range_norm[:,1]
# col 3: DoY
df_range['DoY_norm'] = df_range_norm[:,2]

# %%
# Make a copy to avoid modifying df_train
df_plot = df_range.copy()

# Group by year from the datetime index
df_plot['year'] = df_plot.index.year

plt.figure(figsize=(10, 6))

for year, group in df_plot.groupby('year'):
    plt.scatter(group['x_norm'], group['y_norm'], label=str(year), alpha=0.6)

plt.xlabel('x')
plt.ylabel('y')
plt.title('x vs y for Each Year')
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Step 1: Copy df_train to df_plot
# Step 2: Add 'year' column

# Step 3: Prepare years and subplot grid
years = sorted(df_plot['year'].unique())
n_years = len(years)
n_cols = 3
n_rows = math.ceil(n_years / n_cols)

# Step 4: Generate colormap
cmap = plt.colormaps['viridis']   # Or try 'viridis', 'plasma', 'turbo', etc.
colors = [cmap(i / max(n_years - 1, 1)) for i in range(n_years)]  # Normalize to [0,1]

# Step 5: Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows), sharex=True, sharey=True)
axes = axes.flatten()

for i, year in enumerate(years):
    ax = axes[i]
    yearly_data = df_plot[df_plot['year'] == year]
    ax.scatter(yearly_data['x_norm'], yearly_data['y_norm'], color=colors[i], label=str(year), s = 6)
    ax.set_title(f'Year {year}')
    ax.set_xlabel('Outflow Gage [ft]')
    ax.set_ylabel('Inflow Gage [ft]')

    # Force x-tick labels to be visible
    ax.tick_params(labelbottom=True, labelleft=True)

# Step 6: Remove unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.suptitle('Inflow vs Outflow for Each Year', fontsize=16, y=1.02)
plt.show()

# %%
# Add day-of-year markers
df_plot['day_of_year'] = df_plot.index.strftime('%m-%d')

# Pivot data
pivot = df_plot.pivot_table(index='day_of_year', columns='year', values='x_norm')

# Sort index to ensure proper plotting order
pivot = pivot.sort_index()

# Compute mean across all years
mean_series = pivot.mean(axis=1)

# Plot all years
plt.figure(figsize=(12, 6))
for year in pivot.columns:
    plt.plot(pivot.index, pivot[year], label=str(year), alpha=0.5)

# Plot average line
plt.plot(pivot.index, mean_series, label='Average', color='black', linestyle='--', linewidth=3)

# Show only 10 evenly spaced x-axis labels
xticks_idx = np.linspace(0, len(pivot.index) - 1, 10, dtype=int)
xticks_labels = pivot.index[xticks_idx]
plt.xticks(xticks_idx, xticks_labels, rotation=45)

plt.xlabel('Date [' + str(int_freq) + ' min intervals]')
plt.ylabel('Gage Height [ft]')
plt.title('Overlay of April–Aug Gage Data: Upstream Outflow')
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Regression Analysis

# %%
df_range.tail()
# Out:
#                          y      x  DoY    y_norm    x_norm  DoY_norm
# datetime
# 2024-08-31 21:30:00  75.83  76.41  244  0.134952 -0.641723  1.737665
# 2024-08-31 22:00:00  75.92  76.46  244  0.222454 -0.618237  1.737665
# 2024-08-31 22:30:00  76.11  76.08  244  0.407179 -0.796725  1.737665
# 2024-08-31 23:00:00  76.19  76.22  244  0.484958 -0.730967  1.737665
# 2024-08-31 23:30:00  76.25  76.24  244  0.543293 -0.721573  1.737665

# %% [markdown]
# ## Looped Lag Selection via Residual Scatter Plots

# %%
def lag_selection_via_residuals(upstream, downstream, max_lag=10):
    df = pd.DataFrame({'downstream': downstream})
    for lag in range(1, max_lag + 1):
        df[f'upstream_lag{lag}'] = upstream.shift(lag)
    
    df.dropna(inplace=True)
    X_cols = []
    selected_lags = []

    # Plot setup
    n_plots = max_lag - 1
    n_cols = 3
    n_rows = math.ceil(n_plots / n_cols)
    fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 4))
    axs = axs.flatten()

    for lag in range(1, max_lag):
        lag_col = f'upstream_lag{lag}'
        next_lag_col = f'upstream_lag{lag + 1}'
        X_cols.append(lag_col)
        selected_lags.append(lag_col)

        model = LinearRegression().fit(df[X_cols], df['downstream'])
        df['residual'] = df['downstream'] - model.predict(df[X_cols])

        ax = axs[lag - 1]
        ax.scatter(df[next_lag_col], df['residual'], alpha=0.6)
        ax.set_title(f'Residual vs. {next_lag_col}')
        ax.set_xlabel(next_lag_col)
        ax.set_ylabel('Residual')
        ax.grid(True)

    for i in range(n_plots, len(axs)):
        fig.delaxes(axs[i])

    fig.tight_layout()
    plt.show()

    return model, selected_lags

# %%
upstream = df_range['x_norm'].copy()
downstream = df_range['y_norm'].copy()

_, selected_lags = lag_selection_via_residuals(upstream, downstream)

# %%
_, selected_lags = lag_selection_via_residuals(downstream, downstream)

# %% [markdown]
# ## AR(p) Model to predict Inflow

# %%
df_reg = df_range.copy()

p = 6 + 1 # 30 min intervals

up_feat = True
down_feat = True

# Adding upstream lag features to the DataFrame
if up_feat: 
    for i in range(1, p):  # Creating lag features up to p time units
        df_reg[f'X_Lag_{i}'] = df_reg['x_norm'].shift(i)

if down_feat: 
    # Adding downstream lag features to the DataFrame
    for i in range(1, p):  # Creating lag features up to p time units
        df_reg[f'Y_Lag_{i}'] = df_reg['y_norm'].shift(i)

# Drop rows with NaN values resulting from creating lag features
df_reg.dropna(inplace=True)
df_reg = df_reg.rename(columns={1: '1'})

# Split the data into training and testing sets
train_data = df_reg[(df_reg.index <= train_end_date)]
test_data = df_reg[(df_reg.index >= test_start_date)]

# Define features and target
if up_feat and down_feat: 
    feature_cols = [f'X_Lag_{lag}' for lag in range(1, p) if lag != 2] + [f'Y_Lag_{lag}' for lag in range(1, p) if lag != 3]
if up_feat and not down_feat: 
    feature_cols = ['DoY_norm', 'x_norm'] + [f'X_Lag_{lag}' for lag in range(1, p)] 
if down_feat and not up_feat: 
    feature_cols = ['DoY_norm'] + [f'Y_Lag_{lag}' for lag in range(1, p)]
    
X_train = train_data[feature_cols]
y_train = train_data['y_norm']

# %%
X_test = test_data[feature_cols]
y_test = test_data['y_norm']

# %%
X_train.columns
# Out:
# Index(['X_Lag_1', 'X_Lag_3', 'X_Lag_4', 'X_Lag_5', 'X_Lag_6', 'Y_Lag_1',
#        'Y_Lag_2', 'Y_Lag_4', 'Y_Lag_5', 'Y_Lag_6'],
#       dtype='object')

# %%
X_train.head()
# Out:
#                       X_Lag_1   X_Lag_3   X_Lag_4   X_Lag_5   X_Lag_6  \
# datetime
# 2009-04-01 03:00:00 -0.463486 -0.450150 -0.432369 -0.396806 -0.355202
# 2009-04-01 03:30:00 -0.465709 -0.459041 -0.450150 -0.432369 -0.396806
# 2009-04-01 04:00:00 -0.466820 -0.463486 -0.459041 -0.450150 -0.432369
# 2009-04-01 04:30:00 -0.467376 -0.465709 -0.463486 -0.459041 -0.450150
# 2009-04-01 05:00:00 -0.467654 -0.466820 -0.465709 -0.463486 -0.459041
#
#                       Y_Lag_1   Y_Lag_2   Y_Lag_4   Y_Lag_5   Y_Lag_6
# datetime
# 2009-04-01 03:00:00  0.475236  0.543293  0.601627  0.679406  0.621072
# 2009-04-01 03:30:00  0.397457  0.475236  0.562737  0.601627  0.679406
# 2009-04-01 04:00:00  0.329400  0.397457  0.543293  0.562737  0.601627
# 2009-04-01 04:30:00  0.348845  0.329400  0.475236  0.543293  0.562737
# 2009-04-01 05:00:00  0.348845  0.348845  0.397457  0.475236  0.543293

# %%
# sklearn linear regression

# model = LinearRegression()
# model.fit(X_train, y_train)

# %%
import statsmodels.api as sm

# Step 1: Add constant (intercept)
X_train_const = sm.add_constant(X_train)

# Step 2: Fit OLS model
model = sm.OLS(y_train, X_train_const).fit(cov_type='HC1') # Heteroskedasticity-consistent

# Step 3: View summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 y_norm   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 6.680e+06
# Date:                Thu, 21 Aug 2025   Prob (F-statistic):               0.00
# Time:                        13:14:18   Log-Likelihood:             1.9501e+05
# No. Observations:              110107   AIC:                        -3.900e+05
# Df Residuals:                  110096   BIC:                        -3.899e+05
# Df Model:                          10
# Covariance Type:                  HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.000      0.955      0.340      -0.000       0.000
# X_Lag_1        0.1355      0.006     23.475      0.000       0.124       0.147
# X_Lag_3        0.1682      0.013     12.541      0.000       0.142       0.194
# X_Lag_4       -0.0839      0.013     -6.291      0.000      -0.110      -0.058
# X_Lag_5       -0.1891      0.010    -19.002      0.000      -0.209      -0.170
# X_Lag_6       -0.0252      0.007     -3.528      0.000      -0.039      -0.011
# Y_Lag_1        1.3193      0.023     56.780      0.000       1.274       1.365
# Y_Lag_2       -0.3047      0.028    -10.919      0.000      -0.359      -0.250
# Y_Lag_4        0.0502      0.016      3.237      0.001       0.020       0.081
# Y_Lag_5       -0.0445      0.015     -2.914      0.004      -0.074      -0.015
# Y_Lag_6       -0.0269      0.006     -4.624      0.000      -0.038      -0.015
# ==============================================================================
# Omnibus:                    99766.747   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        514868549.543
# Skew:                          -2.885   Prob(JB):                         0.00
# Kurtosis:                     337.951   Cond. No.                         153.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %%
residuals = model.resid
fitted_vals = model.fittedvalues

# %%
plot_acf(residuals)
plt.show()

# %%
plt.hist(residuals.to_numpy(), bins = 500)
plt.title('Distribution of Training Residuals')
plt.ylabel('Frequency')
plt.xlabel('Error [ft]')
plt.xlim([-.2, .2])
plt.show()

# %%
# Loose reconstruction 

scaler.mean_, scaler.scale_
# Out:
# (array([ 75.69119471,  77.77622353, 167.25      ]),
#  array([ 1.02855296,  2.12899378, 44.16847481]))

# %% [markdown]
# ### Checking for Heteroskedasticity

# %%
# 1. Residuals vs. Fitted Plot

plt.figure(figsize=(8, 5))
sns.scatterplot(x=fitted_vals, y=residuals, alpha=0.7)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Fitted Values vs. Residuals")
plt.grid(True)
plt.show()

# %%
# 2. Breusch-Pagan Test: tests if residual variance is dependent on fitted values

bp_test = sms.het_breuschpagan(residuals, X_train_const)

bp_labels = ['Lagrange multiplier statistic', 'p-value', 
             'f-value', 'f p-value']
print("\nBreusch-Pagan test results:")
for name, val in zip(bp_labels, bp_test):
    print(f"{name}: {val:.4f}")
# Out:
# Breusch-Pagan test results:
# Lagrange multiplier statistic: 294.9534
# p-value: 0.0000
# f-value: 29.5716
# f p-value: 0.0000

# %% [markdown]
# ### Evaluation on Test Data

# %%
X_test_const = sm.add_constant(X_test)  # Add intercept term
X_test_const['const'] = np.ones(len(X_test))
X_test_const = pd.DataFrame(X_test_const, columns=model.model.exog_names)
y_pred = model.predict(X_test_const)

# %%
# Evaluate Performance 

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'RMSE: {rmse:.3f}')
print(f'MAE: {mae:.3f}')
print(f'R²: {r2:.3f}')
# Out:
# RMSE: 0.042
# MAE: 0.028
# R²: 0.997

# %%
plt.figure(figsize=(10, 4))
plt.plot(y_test.index, y_test.values, label='Actual')
plt.plot(y_test.index, y_pred.values, label='Predicted', linestyle='--')
plt.title('Model Predictions vs Actual (5 Months)')
plt.legend()
plt.xlabel('Time Index')
plt.ylabel('Gage Height [normalized]')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(y_test.index[-48:], y_test.values[-48:], label='Actual')
plt.plot(y_test.index[-48:], y_pred.values[-48:], label='Predicted', linestyle='--')
plt.title('Model Predictions vs Actual (24 Hours)')
plt.legend()
plt.xlabel('Time Index')
plt.ylabel('Gage Height [normalized]')
plt.xticks(rotation=-45)
plt.tight_layout()
plt.show()

# %%
test_residuals = y_test - y_pred
plt.hist(test_residuals, bins = 500)
plt.title('Distribution of Testing Residuals')
plt.ylabel('Frequency')
plt.xlabel('Error [ft]')
plt.xlim([-.2, .2])
plt.show()

# %% [markdown]
# ## Residual Analysis

# %%
date_strings = X_train.index.strftime('%Y-%m-%d').to_numpy()

plt.scatter(date_strings, residuals.to_numpy(), s = 2)

# Set how many x-axis labels you want
num_labels_to_show = 15

# Calculate evenly spaced indices
indices = np.linspace(0, len(date_strings) - 1, num_labels_to_show, dtype=int)
selected_dates = date_strings[indices]

# Apply sampled ticks and rotated labels
ax = plt.gca()
ax.set_xticks(selected_dates)
ax.set_xticklabels(selected_dates, rotation=-45)
ax.set_ylim([-1.75, 1.75])

plt.title("Dry Season Training Residuals")
plt.show()

# %%
plt.scatter(date_strings, abs(residuals.to_numpy()), s = 2)

# Apply sampled ticks and rotated labels
ax = plt.gca()
ax.set_xticks(selected_dates)
ax.set_xticklabels(selected_dates, rotation=-45)
ax.set_ylim([0, 1.75])

plt.title("Dry Season Training abs(Residuals)")

plt.show()

# %%
## Scatter the residuals for the final year

index23 = X_train[X_train.index >= '2023-' + month_start].index
res23 = residuals[len(residuals)-len(index23):]

plt.scatter(index23, res23, s =4)
plt.title("2023 Dry Season Residuals")
plt.xticks(rotation=-45)
plt.show()

# %%
## Scatter the abs(residuals) for the final year

plt.scatter(index23, abs(res23), s =4)
plt.title("2023 Dry Season abs(Residuals)")
plt.xticks(rotation=-45)
plt.show()

# %%
## Plot the smoothed residuals for the final year

win = 500

plt.plot(date_strings, abs(residuals).rolling(window=win).mean())

# Apply sampled ticks and rotated labels
ax = plt.gca()
ax.set_xticks(selected_dates)
ax.set_xticklabels(selected_dates, rotation=-45)
#ax.set_ylim([0, 1.75])

plt.title("Dry Season Smoothed Residuals")

plt.show()

# %%
## Plot the smoothed residuals for the final year

plt.plot(index23, abs(res23).rolling(window=win).mean() )
plt.title("2023 Dry Season Smoothed abs(Residuals)")
plt.xticks(rotation=-45)
plt.show()

# %% [markdown]
# ### (decom) ARIMAX Model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

p = max_lag
d = 5 # differencing
q = 2

# y = downstream inflow
# X = matrix of lagged upstream outflows
# ARIMA_model = SARIMAX(y_train, exog=X_train, order=(p, d, q))
# AR_results = ARIMA_model.fit()
# print(AR_results.summary())

# write a full block of code that does lagging, stationarity testing, and grid search over q?

# %% [markdown]
# # Predicting Residuals

# %%
y_res = abs(residuals).rolling(window=win).mean()

# %%
# Drop any NaNs from lag alignment
garch_df = pd.concat([X_train, y_res], axis=1).dropna()

X = garch_df['X_Lag_3'] # replacing x_norm since more powerful feature
y = garch_df[0]

# %%
from arch import arch_model

# Fit a GARCH(p,q) model with exogenous regressors
garch_model = arch_model(
    y, 
    x=X, 
    mean='LS',       # Least Squares for conditional mean
    vol='GARCH',     # GARCH model for conditional variance
    p=1, q = 1,          # GARCH(max_lag,1)
    rescale=True
)

garch_model_fit = garch_model.fit(disp="off")
print(garch_model_fit.summary())
# Out:
#                      Least Squares - GARCH Model Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                      -0.057
# Mean Model:             Least Squares   Adj. R-squared:                 -0.057
# Vol Model:                      GARCH   Log-Likelihood:               -34719.4
# Distribution:                  Normal   AIC:                           69448.8
# Method:            Maximum Likelihood   BIC:                           69496.9
#                                         No. Observations:               109608
# Date:                Thu, Aug 21 2025   Df Residuals:                   109606
# Time:                        13:14:31   Df Model:                            2
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# Const          2.4637  3.453e-03    713.504      0.000     [  2.457,  2.471]
# x0             0.0748  4.537e-03     16.486  4.602e-61 [6.590e-02,8.369e-02]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      5.6245e-03  3.472e-05    162.018      0.000 [5.556e-03,5.693e-03]
# alpha[1]       0.2000  1.371e-03    145.856      0.000     [  0.197,  0.203]
# beta[1]        0.7800  1.327e-03    587.723      0.000     [  0.777,  0.783]
# ============================================================================
#
# Covariance estimator: robust

# %%
res_date_strings = date_strings[(win-1):].copy()

plt.figure(figsize=(10, 2))
plt.plot(res_date_strings, garch_model_fit.conditional_volatility)

# Apply sampled ticks and rotated labels
ax = plt.gca()

# Calculate evenly spaced indices
num_labels_to_show = 14
indices = np.linspace(0, len(res_date_strings) - 1, num_labels_to_show, dtype=int)
selected_dates = res_date_strings[indices]

# Apply sampled ticks and rotated labels
ax = plt.gca()
ax.set_xticks(selected_dates)
ax.set_xticklabels(selected_dates, rotation=-45)
plt.title("Dry Season Conditional Volatility")

plt.show()

# %% [markdown]
# # Forecasting Test Set with LinReg + GARCH

# %%
# y_pred gives the mean forecast at each time step

# Forecast residuals from GARCH
y_hat = garch_model_fit.forecast(x=X_test['X_Lag_3'], horizon=len(X_test))

# %%
# Conditional variance

cond_var = y_hat.variance.values[-1]  # Last row contains forecast for len(X_test)
cond_vol = np.sqrt(cond_var)

# So the streamflow at each step is modeled as:
# Y_t ~ Normal(mean=y_pred[t], std=cond_vol[t])

# %%
# 95% confidence interval
upper = y_pred + 1.96 * cond_vol
lower = y_pred - 1.96 * cond_vol

# %%
plt.figure(figsize=(14, 2))
plt.plot(y_test.index, y_test, label="Actual Streamflow")
plt.plot(y_test.index, y_pred, label="Predicted Streamflow")
plt.fill_between(y_test.index, lower, upper, color='gray', alpha=0.3, label="95% CI")
plt.legend()
plt.title("Forecast with Uncertainty")
plt.show()

# %%
cond_vol
# Out:
# array([0.35910945, 0.363326  , 0.3674113 , ..., 0.53039529, 0.53039529,
#        0.53039529])

# %%
garch_model_fit.conditional_volatility
# Out:
# datetime
# 2009-04-11 12:30:00    0.569887
# 2009-04-11 13:00:00    0.595319
# 2009-04-11 13:30:00    0.612588
# 2009-04-11 14:00:00    0.630249
# 2009-04-11 14:30:00    0.642906
#                          ...
# 2023-08-30 22:00:00    0.367538
# 2023-08-30 22:30:00    0.364052
# 2023-08-30 23:00:00    0.363049
# 2023-08-30 23:30:00    0.363719
# 2023-08-31 00:00:00    0.361802
# Name: cond_vol, Length: 109608, dtype: float64
